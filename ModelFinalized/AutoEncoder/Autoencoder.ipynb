# %% [markdown]
# # Import & Read

# %% [markdown]
# ### import

# %%
from calendar import month_abbr

import pandas as pd
pd.set_option("display.max_columns", None)
import numpy as np

from sklearn.preprocessing import LabelEncoder, MinMaxScaler

import tensorflow as tf
from tensorflow.keras.layers import Dense, Flatten, Embedding, Input, BatchNormalization
from tensorflow.keras.models import Model
from tensorflow.keras.utils import to_categorical

gpus = tf.config.list_physical_devices(device_type="GPU")
tf.config.experimental.set_memory_growth(gpus[0], True)

# %% [markdown]
# ### func

# %%
def drop_useless_rows(df):
    df = df.dropna(subset=["battery_date", "Standard Sensor size"])
    df = df[~df["phone"].isin(["Black Shark 5", "Vivo X80 Pro"])]
    return df

def get_month_no(df):
    df[["launch_month", "launch_year"]] = df["battery_date"].str.split(" ", expand=True)
    df["launch_month"] = df["launch_month"]\
                                    .str[:3].apply(lambda x: np.where(np.array(month_abbr) == x)[0][0])\
                                    .apply(lambda x: str(x).zfill(2))

    df["month_no"] = df[["launch_year", "launch_month"]].apply(lambda x: f"{x['launch_year']}{x['launch_month']}", axis=1)
    df = df.drop(["battery_date", "launch_year", "launch_month"], axis=1)
    return df

def deal_resistence(df):
    df["Resistance certificates (dust, water)"] = df["Resistance certificates (dust, water)"].fillna("")
    df["temp"] = df["Resistance certificates (dust, water)"].str.split(",")

    df["Mil Spec"] = df["temp"].apply(lambda x: x[1] if len(x) == 2 else np.nan)
    df["IP Grade"] = df["temp"].apply(lambda x: x[0])
    return df

def deal_battery_Operating_System(df):
    def func(x):
        if "(" in x:
            x = x.split("(")[1]
        
        x = " ".join(x.split(" ")[:2])
        x = x.replace(")", "")
        return x
    
    df["battery_Operating System"] = df["battery_Operating System"].str.split("\n").str[-1].apply(lambda x: func(x))
    return df

def deal_columns(df):
    df = df.rename(columns={"battery_Google Services (official)":"Google Services(official)",
                            "battery_Operating System":"Operating System",
                            "battery_brand":"Brand",
                            "battery_Capacity":"Battery Capacity",
                            "battery_Type":"Battery Type",
                            "battery_Fast charge":"Battery Fast charge"})
    for col in df.columns:
        df[col] = df[col].str.strip()

    df = df.drop(["Resistance certificates (dust, water)", "temp", "Colors", "Unnamed: 66", "Others", "battery_Others", "battery_Extra", "Score"], axis=1)
    return df

# %% [markdown]
# ### basic tidy

# %%
df_general_spec = pd.read_csv("C:/Users/user/Desktop/park/회사 업무/PhoneData/crawler/result.csv").drop("Unnamed: 0", axis=1)
df_battery_spec = pd.read_csv("C:/Users/user/Desktop/park/회사 업무/PhoneData/crawler/battery.csv").drop("Unnamed: 0", axis=1)
df_battery_spec.columns = ["battery_"+col for col in df_battery_spec.columns]

# concat data
df_spec_raw = pd.concat([df_general_spec, df_battery_spec], axis=1)
print(df_general_spec.shape)
print(df_battery_spec.shape)
print(df_spec_raw.shape)

# basic tidy data
df_spec_raw = drop_useless_rows(df_spec_raw)
df_spec_raw = get_month_no(df_spec_raw)
df_spec_raw = deal_resistence(df_spec_raw)
df_spec_raw = deal_battery_Operating_System(df_spec_raw)
df_spec_raw = deal_columns(df_spec_raw)

df_spec_raw.head(2)
# Out:
# (1484, 97)
# (1484, 11)
# (1484, 108)
#              phone                         Size Weight Usable surface  \
# 0  Vivo iQOO 9 Pro  75.2 mm • 164.8 mm • 9.2 mm  204 g           89 %
# 1  Vivo iQOO 9 Pro  75.2 mm • 164.8 mm • 9.2 mm  204 g           89 %
#
#          Materials Diagonal             Type Aspect Ratio  \
# 0  Aluminium alloy    6.78"  UFS Storage 3.1         20:9
# 1  Aluminium alloy    6.78"  UFS Storage 3.1         20:9
#
#                Resolution    Density            Audio  \
# 0  1440 x 3200 px • WQHD+  518 ppi •  Stereo Speakers
# 1  1440 x 3200 px • WQHD+  518 ppi •  Stereo Speakers
#
#                         Model  \
# 0  Qualcomm Snapdragon 8 Gen1
# 1  Qualcomm Snapdragon 8 Gen1
#
#                                                  CPU Nanometer Frequency  \
# 0  1x3.0GHz Cortex X2 + 3x2.5GHz Cortex A710 + 4x...      4 nm     3 GHz
# 1  1x3.0GHz Cortex X2 + 3x2.5GHz Cortex A710 + 4x...      4 nm     3 GHz
#
#   64 Bits         GPU    RAM Capacity SD Slot Fingerprint Proximity  \
# 0     Yes  Adreno 730  12 GB   256 GB      No         Yes       Yes
# 1     Yes  Adreno 730   8 GB   256 GB      No         Yes       Yes
#
#   Light sensor Accelerometer Compass Gyroscope  RGB Notifications LED  \
# 0          Yes           Yes     Yes       Yes  Yes                --
# 1          Yes           Yes     Yes       Yes  Yes                --
#
#   Cooling system Gaming buttons  \
# 0            Yes             No
# 1            Yes             No
#
#                                                Extra Standard Resolution  \
# 0  Dual linear motorDual-control pressure sensing...              50 Mpx
# 1  Dual linear motorDual-control pressure sensing...              50 Mpx
#
#   Standard Sensor Standard Type Standard Aperture Standard ISO  \
# 0     Samsung GN5       ISOCELL           ƒ/ 1.75           --
# 1     Samsung GN5       ISOCELL           ƒ/ 1.75           --
#
#   Standard Pixel size Standard Pixel Binning Standard Sensor size  \
# 0             1.00 µm              1-4 (2x2)               1/1.57
# 1             1.00 µm              1-4 (2x2)               1/1.57
#
#   Wide Angle lens Resolution Wide Angle lens Sensor Wide Angle lens Type  \
# 0                     50 Mpx         Samsung S5KJN1              ISOCELL
# 1                     50 Mpx         Samsung S5KJN1              ISOCELL
#
#   Wide Angle lens Aperture Wide Angle lens Pixel size  \
# 0                  ƒ/ 2.27                    0.64 µm
# 1                  ƒ/ 2.27                    0.64 µm
#
#   Wide Angle lens Pixel Binning Wide Angle lens Sensor size  \
# 0                     1-4 (2x2)                      1/2.76
# 1                     1-4 (2x2)                      1/2.76
#
#   Portrait mode (depth) Resolution Portrait mode (depth) Sensor  \
# 0                           16 Mpx               Samsung S5K3P9
# 1                           16 Mpx               Samsung S5K3P9
#
#   Portrait mode (depth) Type Portrait mode (depth) Aperture  \
# 0                    ISOCELL                        ƒ/ 2.23
# 1                    ISOCELL                        ƒ/ 2.23
#
#   Portrait mode (depth) Pixel size Portrait mode (depth) Pixel Binning  \
# 0                          1.00 µm                           1-4 (2x2)
# 1                          1.00 µm                           1-4 (2x2)
#
#   Portrait mode (depth) Sensor size Hall Macro lens Aperture  \
# 0                             1/3.1  NaN                 NaN
# 1                             1/3.1  NaN                 NaN
#
#   Macro lens Pixel size Macro lens Resolution Macro lens Sensor  \
# 0                   NaN                   NaN               NaN
# 1                   NaN                   NaN               NaN
#
#   Macro lens Sensor size Macro lens Type Ultrasonic proximity virtual  \
# 0                    NaN             NaN                          NaN
# 1                    NaN             NaN                          NaN
#
#   Barometer Geomagnetic Telephoto + portrait Aperture  \
# 0       NaN         NaN                           NaN
# 1       NaN         NaN                           NaN
#
#   Telephoto + portrait Pixel size Telephoto + portrait Resolution  \
# 0                             NaN                             NaN
# 1                             NaN                             NaN
#
#   Telephoto + portrait Sensor Telephoto + portrait Sensor size  \
# 0                         NaN                              NaN
# 1                         NaN                              NaN
#
#   Telephoto + portrait Type Cooling System Heart Rate Gravity Magnetometer  \
# 0                       NaN            NaN        NaN     NaN          NaN
# 1                       NaN            NaN        NaN     NaN          NaN
#
#   LiDAR Scanner Red Core 1 Game chip Display Pressure Touch BLE S Pen  \
# 0           NaN                  NaN              NaN   NaN       NaN
# 1           NaN                  NaN              NaN   NaN       NaN
#
#   Hardware Utrasonic Fingerprint Pedometer Telephoto + portrait Pixel Binning  \
# 0      NaN                   NaN       NaN                                NaN
# 1      NaN                   NaN       NaN                                NaN
#
#   Altimeter Temperature 360° ambient light sensor Iris scanner Thermometer  \
# 0       NaN         NaN                       NaN          NaN         NaN
# 1       NaN         NaN                       NaN          NaN         NaN
#
#   Coulometer  Secondary UV light sensor Humidity Hall IC Brand  \
# 0        NaN        NaN             NaN      NaN     NaN  Vivo
# 1        NaN        NaN             NaN      NaN     NaN  Vivo
#
#              Battery Capacity Battery Type Battery Fast charge  \
# 0  4700 mAh\nSee more details      Lithium        Yes , 120.0W
# 1  4700 mAh\nSee more details      Lithium        Yes , 120.0W
#
#   Operating System Google Services(official) battery_Widevine L1  \
# 0       Android 12                        No                 NaN
# 1       Android 12                        No                 NaN
#
#   battery_Widevine L3 month_no Mil Spec IP Grade
# 0                 NaN   202201      NaN
# 1                 NaN   202201      NaN

# %% [markdown]
# # Data Cleanse

# %% [markdown]
# ### cleanse

# %%
def drop_old_phones(df, start_month=None, end_month=None):
    if not start_month: start_month = df["month_no"].min()
    if not end_month: end_month = df["month_no"].max()

    df = df[
        (df["month_no"] >= start_month)
        &(df["month_no"] <= end_month)
    ]
    return df

def deal_GBs(df):
    for col in ["RAM", "Capacity"]:
        df[f"{col}_"] = df[f"{col}"].apply(lambda x: float(x.replace("TB", ""))*1024 if "TB" in x else float(x.replace("GB", "")))
        df[f"{col}_max"] = df.groupby("phone")[f"{col}_"].transform(max)
        df = df[df[f"{col}_"] == df[f"{col}_max"]]
        df = df.drop([f"{col}_", f"{col}_max"], axis=1)
    return df

def deal_google_services(df):
    df = df.drop("Google Services(official)", axis=1)
    return df

def deal_operating_sys(df):
    df["temp"] = df["Operating System"].str.split(" ").str[1].str[:3].astype(float)
    df["max"] = df.groupby("phone")["temp"].transform(max)
    df = df[df["temp"] == df["max"]]
    df = df.drop(["temp", "max"], axis=1)
    return df

def deal_diagonal(df):
    df["temp"] = df["Diagonal"].str.replace('"', "").astype(float)
    df["max"] = df.groupby("phone")["temp"].transform(max)
    df = df[df["temp"] == df["max"]]
    df = df.drop(["temp", "max"], axis=1)
    return df

def deal_model(df):
    df = df[
        ~((df["phone"] == "Samsung Galaxy A71 5G") & (df["Model"] == "Qualcomm Snapdragon 765G"))
        &~((df["phone"] == "Samsung Galaxy Note10") & (df["Model"] == "Qualcomm Snapdragon 855"))
        &~((df["phone"] == "Samsung Galaxy Note20 Ultra") & (df["Model"] == "Qualcomm Snapdragon 865+"))
        &~((df["phone"] == "Samsung Galaxy S10") & (df["Model"] == "Qualcomm Snapdragon 855"))
        &~((df["phone"] == "Samsung Galaxy S10 Plus") & (df["Model"] == "Qualcomm Snapdragon 855"))
        &~((df["phone"] == "Samsung Galaxy S10e") & (df["Model"] == "Qualcomm Snapdragon 855"))
        &~((df["phone"] == "Samsung Galaxy S20 Ultra") & (df["Model"] == "Qualcomm Snapdragon 865"))
        &~((df["phone"] == "Samsung Galaxy S21 Ultra") & (df["Model"] == "Qualcomm Snapdragon 888"))
        &~((df["phone"] == "Samsung Galaxy S22") & (df["Model"] == "Qualcomm Snapdragon 8 Gen1"))
        &~((df["phone"] == "Samsung Galaxy S22 Ultra") & (df["Model"] == "Qualcomm Snapdragon 8 Gen1"))
        &~((df["phone"] == "Samsung Galaxy S22+") & (df["Model"] == "Qualcomm Snapdragon 8 Gen1"))
        &~((df["phone"] == "Samsung Galaxy S8") & (df["Model"] == "Qualcomm Snapdragon 835"))
        &~((df["phone"] == "Samsung Galaxy S9") & (df["Cooling system"] == "Yes"))
        &~((df["phone"] == "Xiaomi Redmi Note 10 Pro") & (df["Standard Sensor"] == "Samsung S5KHM2"))
        &~((df["phone"] == "Motorola Moto G9 Play") & (df["Compass"] == "Yes"))
        &~((df["phone"] == "Motorola One Vision") & (df["Resolution"] == "1080 x 2520 px • FHD+"))
        &~((df["phone"] == "Samsung Galaxy M12") & (df["Wide Angle lens Resolution"] == "5 Mpx"))
        &~((df["phone"] == "Vivo X60 Pro+") & (df["Gravity"] == "Yes"))
        &~((df["phone"] == "Xiaomi Redmi Note 9 Pro") & (df["Notifications LED"] == "LED Notifications"))
        &~((df["phone"] == "realme 6 Pro") & (df["Geomagnetic"] == "Yes"))
    ]
    return df

def deal_score(df):
    df["temp"] = df["Score"].astype(float)
    df["max"] = df.groupby("phone")["temp"].transform(max)
    df = df[df["temp"] == df["max"]]
    df = df.drop(["temp", "max"], axis=1)
    return df

def check_duplicates(df):
    duplicate_phone_li = df.groupby("phone").size()
    duplicate_phone_li = duplicate_phone_li[duplicate_phone_li > 1].index.to_list()
    print(len(duplicate_phone_li))

    valid_idx_li = []
    is_stop = False
    for phone in duplicate_phone_li:
        df = df[df["phone"] == phone]
        idx = df.index

        for col in df.columns:
            val = df[col].values
            if len(set(val)) != 1: # 중복이 있는 컬럼을 처리
                print(col)
                display(df[["phone", col]])
                is_stop = True
            
        if is_stop:
            break

# %%
df_spec = df_spec_raw.copy()

# cleanse
df_spec = drop_old_phones(df_spec, start_month="201701")
df_spec = deal_GBs(df_spec)
df_spec = deal_google_services(df_spec)
df_spec = deal_operating_sys(df_spec)
df_spec = deal_diagonal(df_spec)
df_spec = deal_model(df_spec)

df_spec = df_spec.drop_duplicates().reset_index(drop=True)

print(df_spec.shape)
check_duplicates(df_spec)
# Out:
# (424, 102)
# 0

# %% [markdown]
# ### deal numeric

# %%
def size_func(x):
    x = x.replace("mm", "").split("•")
    res = 1
    for i in x:
        res *= float(i)
    return res

def resolution_func(x):
    x = x["Resolution"].split("•")

    # resolution1
    x[0] = x[0].replace("px", "").split("x")
    x[0] = float(x[0][0]) * float(x[0][1])

    # resolution2
    try :
        x[0] = x[1].strip()
    except IndexError:
        x.append("")
    
    return x

def capacity_func(x):
    if "TB" in x :
        x = float(x.replace("TB", ""))
        x *= 1024
    elif "GB" in x:
        x = float(x.replace("GB", ""))
    return x

def battery_fast_charge_func(x):
    x = x["Battery Fast charge"].split(",")
    x[0] = x[0].strip()

    try:
        x[1] = float(x[1].replace("W", ""))
    except IndexError:
        x.append(0)
    return x

def month_diff_func(x):
    x["month_no"] = pd.to_datetime(x["month_no"], format="%Y%m")
    x["Month Max"] = pd.to_datetime(x["Month Max"], format="%Y%m")
    x["Month Diff"] = np.round((x["Month Max"] - x["month_no"]) / np.timedelta64(1, "M"))

    return x["Month Diff"]

# %%
df_final = df_spec.copy()

df_final["Size"] = df_final["Size"].apply(lambda x: size_func(x)) # width X height X depth 값
df_final["Weight"] = df_final["Weight"].apply(lambda x: float(x.replace("g", "")))
df_final["Usable surface"] = df_final["Usable surface"].apply(lambda x: float(x.replace("%", "")))
df_final["Diagonal"] = df_final["Diagonal"].apply(lambda x: float(x.replace('"', "")))
df_final[["Resolution1", "Resolution2"]] = df_final.apply(lambda x: resolution_func(x), axis=1, result_type="expand")
df_final["Density"] = df_final["Density"].apply(lambda x: float(x.replace("ppi", "").replace("•", "")))
df_final["Nanometer"] = df_final["Nanometer"].apply(lambda x: float(x.replace("nm", "")))
df_final["Frequency"] = df_final["Frequency"].apply(lambda x: float(x.replace("GHz", "")))
df_final["RAM"] = df_final["RAM"].apply(lambda x: float(x.replace("GB", "")))
df_final["Capacity"] = df_final["Capacity"].apply(lambda x: capacity_func(x))
df_final["Battery Capacity"] = df_final["Battery Capacity"].apply(lambda x: float(x.split("\n")[0].replace("mAh", "")))
df_final[["Fast charge", "Charge Watt"]] = df_final.apply(lambda x: battery_fast_charge_func(x), axis=1, result_type="expand")
df_final["Month Max"] = df_final["month_no"].max()
df_final["Month Diff"] = df_final.apply(lambda x: month_diff_func(x), axis=1)

df_final = df_final.drop(["Resolution", "Battery Fast charge", "month_no", "Month Max"], axis=1)
print(df_final.shape)
df_final.head(3)
# Out:
# (424, 104)
#               phone        Size  Weight  Usable surface        Materials  \
# 0   Vivo iQOO 9 Pro  114015.232   204.0            89.0  Aluminium alloy
# 1       Vivo iQOO 9  105984.060   206.0            87.0  Aluminium alloy
# 2  Xiaomi Mi 11 Pro  104182.630   208.0            91.0            Glass
#
#    Diagonal             Type Aspect Ratio  Density  \
# 0      6.78  UFS Storage 3.1         20:9    518.0
# 1      6.78  UFS Storage 3.1         20:9    388.0
# 2      6.81  UFS Storage 3.1         20:9    515.0
#
#                                       Audio                       Model  \
# 0                           Stereo Speakers  Qualcomm Snapdragon 8 Gen1
# 1                           Stereo Speakers  Qualcomm Snapdragon 8 Gen1
# 2  Hi-Res AudioStereo Speakers3 microphones     Qualcomm Snapdragon 888
#
#                                                  CPU  Nanometer  Frequency  \
# 0  1x3.0GHz Cortex X2 + 3x2.5GHz Cortex A710 + 4x...        4.0       3.00
# 1  1x3.0GHz Cortex X2 + 3x2.5GHz Cortex A710 + 4x...        4.0       3.00
# 2  1x Cortex X1 2.84GHz + 3x Cortex A78 2.42GHz +...        5.0       2.84
#
#   64 Bits         GPU   RAM  Capacity SD Slot Fingerprint Proximity  \
# 0     Yes  Adreno 730  12.0     512.0      No         Yes       Yes
# 1     Yes  Adreno 730  12.0     512.0      No         Yes       Yes
# 2     Yes  Adreno 660  12.0     256.0      No         Yes       Yes
#
#   Light sensor Accelerometer Compass Gyroscope  RGB Notifications LED  \
# 0          Yes           Yes     Yes       Yes  Yes                --
# 1          Yes           Yes     Yes       Yes  NaN                --
# 2          Yes           Yes     Yes       Yes  NaN                --
#
#   Cooling system Gaming buttons  \
# 0            Yes             No
# 1            Yes             No
# 2            Yes             No
#
#                                                Extra Standard Resolution  \
# 0  Dual linear motorDual-control pressure sensing...              50 Mpx
# 1  Dual linear motorDual-control pressure sensing...              50 Mpx
# 2  X-axis Linear motorLiquid-cooled VC three-dime...              50 Mpx
#
#   Standard Sensor Standard Type Standard Aperture Standard ISO  \
# 0     Samsung GN5       ISOCELL           ƒ/ 1.75           --
# 1     Samsung GN5       ISOCELL           ƒ/ 1.75           --
# 2     Samsung GN2       ISOCELL           ƒ/ 1.95           --
#
#   Standard Pixel size Standard Pixel Binning Standard Sensor size  \
# 0             1.00 µm              1-4 (2x2)               1/1.57
# 1             1.00 µm              1-4 (2x2)               1/1.57
# 2             0.70 µm              1-4 (2x2)               1/1.12
#
#   Wide Angle lens Resolution Wide Angle lens Sensor Wide Angle lens Type  \
# 0                     50 Mpx         Samsung S5KJN1              ISOCELL
# 1                     13 Mpx         Samsung S5K3L6              ISOCELL
# 2                     13 Mpx     Omnivision OV13B10              PureCel
#
#   Wide Angle lens Aperture Wide Angle lens Pixel size  \
# 0                  ƒ/ 2.27                    0.64 µm
# 1                   ƒ/ 2.2                    1.12 µm
# 2                   ƒ/ 2.2                    1.12 µm
#
#   Wide Angle lens Pixel Binning Wide Angle lens Sensor size  \
# 0                     1-4 (2x2)                      1/2.76
# 1                           NaN                       1/3.1
# 2                           NaN                      1/3.06
#
#   Portrait mode (depth) Resolution Portrait mode (depth) Sensor  \
# 0                           16 Mpx               Samsung S5K3P9
# 1                           12 Mpx                  Sony IMX663
# 2                              NaN                          NaN
#
#   Portrait mode (depth) Type Portrait mode (depth) Aperture  \
# 0                    ISOCELL                        ƒ/ 2.23
# 1                       CMOS                        ƒ/ 1.98
# 2                        NaN                            NaN
#
#   Portrait mode (depth) Pixel size Portrait mode (depth) Pixel Binning  \
# 0                          1.00 µm                           1-4 (2x2)
# 1                          1.22 µm                                 NaN
# 2                              NaN                                 NaN
#
#   Portrait mode (depth) Sensor size Hall Macro lens Aperture  \
# 0                             1/3.1  NaN                 NaN
# 1                            1/2.93  Yes                 NaN
# 2                               NaN  NaN                 NaN
#
#   Macro lens Pixel size Macro lens Resolution Macro lens Sensor  \
# 0                   NaN                   NaN               NaN
# 1                   NaN                   NaN               NaN
# 2                   NaN                   NaN               NaN
#
#   Macro lens Sensor size Macro lens Type Ultrasonic proximity virtual  \
# 0                    NaN             NaN                          NaN
# 1                    NaN             NaN                          NaN
# 2                    NaN             NaN                          NaN
#
#   Barometer Geomagnetic Telephoto + portrait Aperture  \
# 0       NaN         NaN                           NaN
# 1       NaN         NaN                           NaN
# 2       NaN         NaN                           NaN
#
#   Telephoto + portrait Pixel size Telephoto + portrait Resolution  \
# 0                             NaN                             NaN
# 1                             NaN                             NaN
# 2                             NaN                             NaN
#
#   Telephoto + portrait Sensor Telephoto + portrait Sensor size  \
# 0                         NaN                              NaN
# 1                         NaN                              NaN
# 2                         NaN                              NaN
#
#   Telephoto + portrait Type Cooling System Heart Rate Gravity Magnetometer  \
# 0                       NaN            NaN        NaN     NaN          NaN
# 1                       NaN            NaN        NaN     NaN          NaN
# 2                       NaN            NaN        Yes     NaN          NaN
#
#   LiDAR Scanner Red Core 1 Game chip Display Pressure Touch BLE S Pen  \
# 0           NaN                  NaN              NaN   NaN       NaN
# 1           NaN                  NaN              NaN   NaN       NaN
# 2           NaN                  NaN              NaN   NaN       NaN
#
#   Hardware Utrasonic Fingerprint Pedometer Telephoto + portrait Pixel Binning  \
# 0      NaN                   NaN       NaN                                NaN
# 1      NaN                   NaN       NaN                                NaN
# 2      NaN                   NaN       NaN                                NaN
#
#   Altimeter Temperature 360° ambient light sensor Iris scanner Thermometer  \
# 0       NaN         NaN                       NaN          NaN         NaN
# 1       NaN         NaN                       NaN          NaN         NaN
# 2       NaN         NaN                       NaN          NaN         NaN
#
#   Coulometer  Secondary UV light sensor Humidity Hall IC   Brand  \
# 0        NaN        NaN             NaN      NaN     NaN    Vivo
# 1        NaN        NaN             NaN      NaN     NaN    Vivo
# 2        NaN        NaN             NaN      NaN     NaN  Xiaomi
#
#    Battery Capacity    Battery Type Operating System battery_Widevine L1  \
# 0            4700.0         Lithium       Android 12                 NaN
# 1            4700.0         Lithium       Android 12                 NaN
# 2            5000.0  Li-Ion Polymer       Android 12                 Yes
#
#   battery_Widevine L3 Mil Spec IP Grade Resolution1 Resolution2 Fast charge  \
# 0                 NaN      NaN                WQHD+       WQHD+         Yes
# 1                 NaN      NaN                 FHD+        FHD+         Yes
# 2                 NaN      NaN     IP68       WQHD+       WQHD+         Yes
#
#    Charge Watt  Month Diff
# 0        120.0         7.0
# 1        120.0         7.0
# 2         67.0        17.0

# %% [markdown]
# # Model

# %%
df_train = df_final.drop("phone", axis=1).copy()

# cat_cols num_cols split
cat_cols = [col for col in df_train.columns if df_train[col].dtype == "O"]
num_cols = [col for col in df_train.columns if df_train[col].dtype != "O"]
print(cat_cols)
print(num_cols)

# label encode categorical columns
for col in cat_cols:
    encoder = LabelEncoder()
    df_train[col] = encoder.fit_transform(df_train[col].astype(str))

# scale numerical columns
tepm = df_train.copy()
scaler = MinMaxScaler()
df_train[num_cols] = scaler.fit_transform(df_train[num_cols])

# make data_li
cat_train_li = [df_train[col].values.reshape(-1,1) for col in cat_cols]
cat_train = df_train[cat_cols]
num_train = df_train[num_cols]

data_li = cat_train_li + [num_train]

# make label_li
data_label_li = []
for i in cat_train_li:
    data_label_li.append(to_categorical(i))
data_label_li = data_label_li + [num_train]
# Out:
# ['Materials', 'Type', 'Aspect Ratio', 'Audio', 'Model', 'CPU', '64 Bits', 'GPU', 'SD Slot', 'Fingerprint', 'Proximity', 'Light sensor', 'Accelerometer', 'Compass', 'Gyroscope', 'RGB', 'Notifications LED', 'Cooling system', 'Gaming buttons', 'Extra', 'Standard Resolution', 'Standard Sensor', 'Standard Type', 'Standard Aperture', 'Standard ISO', 'Standard Pixel size', 'Standard Pixel Binning', 'Standard Sensor size', 'Wide Angle lens Resolution', 'Wide Angle lens Sensor', 'Wide Angle lens Type', 'Wide Angle lens Aperture', 'Wide Angle lens Pixel size', 'Wide Angle lens Pixel Binning', 'Wide Angle lens Sensor size', 'Portrait mode (depth) Resolution', 'Portrait mode (depth) Sensor', 'Portrait mode (depth) Type', 'Portrait mode (depth) Aperture', 'Portrait mode (depth) Pixel size', 'Portrait mode (depth) Pixel Binning', 'Portrait mode (depth) Sensor size', 'Hall', 'Macro lens Aperture', 'Macro lens Pixel size', 'Macro lens Resolution', 'Macro lens Sensor', 'Macro lens Sensor size', 'Macro lens Type', 'Ultrasonic proximity virtual', 'Barometer', 'Geomagnetic', 'Telephoto + portrait Aperture', 'Telephoto + portrait Pixel size', 'Telephoto + portrait Resolution', 'Telephoto + portrait Sensor', 'Telephoto + portrait Sensor size', 'Telephoto + portrait Type', 'Cooling System', 'Heart Rate', 'Gravity', 'Magnetometer', 'LiDAR Scanner', 'Red Core 1 Game chip', 'Display Pressure', 'Touch', 'BLE S Pen', 'Hardware', 'Utrasonic Fingerprint', 'Pedometer', 'Telephoto + portrait Pixel Binning', 'Altimeter', 'Temperature', '360° ambient light sensor', 'Iris scanner', 'Thermometer', 'Coulometer', ' Secondary', 'UV light sensor', 'Humidity', 'Hall IC', 'Brand', 'Battery Type', 'Operating System', 'battery_Widevine L1', 'battery_Widevine L3', 'Mil Spec', 'IP Grade', 'Resolution1', 'Resolution2', 'Fast charge']
# ['Size', 'Weight', 'Usable surface', 'Diagonal', 'Density', 'Nanometer', 'Frequency', 'RAM', 'Capacity', 'Battery Capacity', 'Charge Watt', 'Month Diff']

# %%
# deal categorical variables
cat_input_li = []
embedded_li = []

for col in cat_cols :
    total_vocab = df_train[col].nunique()
    input = Input(shape=(1,))
    embedding = Embedding(input_dim=total_vocab, output_dim=1024)(input)
    flatten = Flatten()(embedding)

    cat_input_li.append(input)
    embedded_li.append(flatten)

# deal total input
num_input = Input(shape=(num_train.shape[1],), name="num_input")
total_input_li = cat_input_li + [num_input]

# concat layers
concat = tf.keras.layers.concatenate(embedded_li+[num_input])
print(concat.shape)

# encoder
dense = Dense(2**10, activation="selu")(concat)
dense = tf.keras.layers.BatchNormalization()(dense)
dense = Dense(2**9, activation="selu")(concat)
dense = tf.keras.layers.BatchNormalization()(dense)
encoder = Dense(2**8, activation="selu")(concat)
encoder = tf.keras.layers.BatchNormalization()(dense)

# decoder
dense = Dense(2**8, activation="selu")(concat)
dense = tf.keras.layers.BatchNormalization()(dense)
dense = Dense(2**9, activation="selu")(concat)
dense = tf.keras.layers.BatchNormalization()(dense)
dense = Dense(2*10, activation="selu")(concat)
dense = tf.keras.layers.BatchNormalization()(dense)

# deal cat_output_li
cat_output_li = []
for col in cat_cols:
    total_vocab = df_train[col].nunique()
    cat_output = Dense(total_vocab, activation="softmax")(dense)
    cat_output_li.append(cat_output)

# deal num_ouput
num_output = Dense(num_train.shape[1], activation="sigmoid", name="num_output")(dense)

# deal total_output
total_output_li = cat_output_li + [num_output]

# deal loss function
loss_func = ["categorical_crossentropy" for i in cat_cols] + ["binary_crossentropy"]

# model
model = Model(inputs=total_input_li, outputs=total_output_li)
model.compile(loss=loss_func, optimizer=tf.keras.optimizers.Nadam())
lr_schedule = tf.keras.callbacks.ReduceLROnPlateau(patience=5, min_delta=0.01, min_lr=1e-5, monitor="num_output_loss")
early_stopping = tf.keras.callbacks.EarlyStopping(patience=10, min_delta=0.01, monitor="num_output_loss")
model.fit(x=data_li, y=data_label_li, epochs=1000, callbacks=[lr_schedule, early_stopping], batch_size=16)
# Out:
# (None, 93196)
# Epoch 1/1000
# 27/27 [==============================] - 19s 114ms/step - loss: 156.6962 - dense_589_loss: 2.9899 - dense_590_loss: 1.9975 - dense_591_loss: 2.0650 - dense_592_loss: 3.7717 - dense_593_loss: 4.7857 - dense_594_loss: 4.6347 - dense_595_loss: 0.8475 - dense_596_loss: 4.6033 - dense_597_loss: 0.5031 - dense_598_loss: 0.7743 - dense_599_loss: 0.5812 - dense_600_loss: 0.8771 - dense_601_loss: 0.9944 - dense_602_loss: 0.9813 - dense_603_loss: 0.6861 - dense_604_loss: 0.8009 - dense_605_loss: 1.3153 - dense_606_loss: 0.7981 - dense_607_loss: 0.7649 - dense_608_loss: 4.1577 - dense_609_loss: 2.1950 - dense_610_loss: 3.5802 - dense_611_loss: 1.2416 - dense_612_loss: 3.1385 - dense_613_loss: 2.5888 - dense_614_loss: 2.5694 - dense_615_loss: 1.1742 - dense_616_loss: 3.0171 - dense_617_loss: 2.3175 - dense_618_loss: 3.2797 - dense_619_loss: 1.7557 - dense_620_loss: 2.2469 - dense_621_loss: 2.4949 - dense_622_loss: 0.7514 - dense_623_loss: 2.5561 - dense_624_loss: 1.9447 - dense_625_loss: 2.8231 - dense_626_loss: 1.9513 - dense_627_loss: 2.3925 - dense_628_loss: 2.7518 - dense_629_loss: 0.9558 - dense_630_loss: 2.2275 - dense_631_loss: 0.6462 - dense_632_loss: 2.2928 - dense_633_loss: 1.5630 - dense_634_loss: 2.0700 - dense_635_loss: 2.4591 - dense_636_loss: 1.2420 - dense_637_loss: 1.9782 - dense_638_loss: 0.9273 - dense_639_loss: 0.7724 - dense_640_loss: 0.7322 - dense_641_loss: 2.0840 - dense_642_loss: 2.1086 - dense_643_loss: 2.0586 - dense_644_loss: 2.3958 - dense_645_loss: 2.2047 - dense_646_loss: 2.0767 - dense_647_loss: 1.7635 - dense_648_loss: 0.8270 - dense_649_loss: 0.6715 - dense_650_loss: 0.7737 - dense_651_loss: 0.8051 - dense_652_loss: 1.1533 - dense_653_loss: 0.9231 - dense_654_loss: 0.8929 - dense_655_loss: 0.8306 - dense_656_loss: 0.9215 - dense_657_loss: 0.7851 - dense_658_loss: 0.7911 - dense_659_loss: 0.7648 - dense_660_loss: 1.0075 - dense_661_loss: 1.0569 - dense_662_loss: 0.8285 - dense_663_loss: 0.7988 - dense_664_loss: 0.8827 - dense_665_loss: 0.8581 - dense_666_loss: 1.8899 - dense_667_loss: 0.8601 - dense_668_loss: 0.8056 - dense_669_loss: 0.0000e+00 - dense_670_loss: 3.8974 - dense_671_loss: 2.0292 - dense_672_loss: 2.9747 - dense_673_loss: 0.6847 - dense_674_loss: 0.9182 - dense_675_loss: 1.2596 - dense_676_loss: 1.8986 - dense_677_loss: 1.9398 - dense_678_loss: 2.1766 - dense_679_loss: 0.7453 - num_output_loss: 0.7859 - lr: 0.0010
# Epoch 2/1000
# 27/27 [==============================] - 3s 116ms/step - loss: 140.4871 - dense_589_loss: 2.7279 - dense_590_loss: 1.7153 - dense_591_loss: 1.8815 - dense_592_loss: 3.5552 - dense_593_loss: 4.6624 - dense_594_loss: 4.4619 - dense_595_loss: 0.6741 - dense_596_loss: 4.4405 - dense_597_loss: 0.4165 - dense_598_loss: 0.7009 - dense_599_loss: 0.5252 - dense_600_loss: 0.7140 - dense_601_loss: 0.8807 - dense_602_loss: 0.7896 - dense_603_loss: 0.6162 - dense_604_loss: 0.6713 - dense_605_loss: 1.2020 - dense_606_loss: 0.6800 - dense_607_loss: 0.6841 - dense_608_loss: 3.9922 - dense_609_loss: 1.9006 - dense_610_loss: 3.3273 - dense_611_loss: 1.1088 - dense_612_loss: 2.8974 - dense_613_loss: 2.4356 - dense_614_loss: 2.3636 - dense_615_loss: 0.8922 - dense_616_loss: 2.7444 - dense_617_loss: 2.0942 - dense_618_loss: 3.0805 - dense_619_loss: 1.6094 - dense_620_loss: 2.0859 - dense_621_loss: 2.1727 - dense_622_loss: 0.6896 - dense_623_loss: 2.3366 - dense_624_loss: 1.6544 - dense_625_loss: 2.3923 - dense_626_loss: 1.7127 - dense_627_loss: 2.0645 - dense_628_loss: 2.5762 - dense_629_loss: 0.8179 - dense_630_loss: 2.1129 - dense_631_loss: 0.5523 - dense_632_loss: 1.9255 - dense_633_loss: 1.3244 - dense_634_loss: 1.8121 - dense_635_loss: 2.1640 - dense_636_loss: 1.0777 - dense_637_loss: 1.6213 - dense_638_loss: 0.6945 - dense_639_loss: 0.7201 - dense_640_loss: 0.6224 - dense_641_loss: 1.8717 - dense_642_loss: 1.9206 - dense_643_loss: 1.8970 - dense_644_loss: 2.1588 - dense_645_loss: 1.9241 - dense_646_loss: 1.8737 - dense_647_loss: 1.5803 - dense_648_loss: 0.7570 - dense_649_loss: 0.5759 - dense_650_loss: 0.7095 - dense_651_loss: 0.6780 - dense_652_loss: 0.9946 - dense_653_loss: 0.7454 - dense_654_loss: 0.7299 - dense_655_loss: 0.7637 - dense_656_loss: 0.7212 - dense_657_loss: 0.6835 - dense_658_loss: 0.6479 - dense_659_loss: 0.6811 - dense_660_loss: 0.7596 - dense_661_loss: 0.8638 - dense_662_loss: 0.6874 - dense_663_loss: 0.6705 - dense_664_loss: 0.7015 - dense_665_loss: 0.7301 - dense_666_loss: 1.6935 - dense_667_loss: 0.7142 - dense_668_loss: 0.6963 - dense_669_loss: 0.0000e+00 - dense_670_loss: 3.6934 - dense_671_loss: 1.7933 - dense_672_loss: 2.7378 - dense_673_loss: 0.6110 - dense_674_loss: 0.7949 - dense_675_loss: 1.0230 - dense_676_loss: 1.7688 - dense_677_loss: 1.7542 - dense_678_loss: 1.9474 - dense_679_loss: 0.6055 - num_output_loss: 0.7519 - lr: 0.0010
# Epoch 3/1000
# 27/27 [==============================] - 3s 116ms/step - loss: 128.9214 - dense_589_loss: 2.5402 - dense_590_loss: 1.5592 - dense_591_loss: 1.7294 - dense_592_loss: 3.3758 - dense_593_loss: 4.5574 - dense_594_loss: 4.3606 - dense_595_loss: 0.5569 - dense_596_loss: 4.3323 - dense_597_loss: 0.4148 - dense_598_loss: 0.6656 - dense_599_loss: 0.5142 - dense_600_loss: 0.6521 - dense_601_loss: 0.7952 - dense_602_loss: 0.6911 - dense_603_loss: 0.5343 - dense_604_loss: 0.5981 - dense_605_loss: 1.1082 - dense_606_loss: 0.6191 - dense_607_loss: 0.6278 - dense_608_loss: 3.8820 - dense_609_loss: 1.8519 - dense_610_loss: 3.1883 - dense_611_loss: 1.0470 - dense_612_loss: 2.7467 - dense_613_loss: 2.2678 - dense_614_loss: 2.1700 - dense_615_loss: 0.8252 - dense_616_loss: 2.5746 - dense_617_loss: 1.8779 - dense_618_loss: 2.8348 - dense_619_loss: 1.4647 - dense_620_loss: 1.8419 - dense_621_loss: 1.9758 - dense_622_loss: 0.6251 - dense_623_loss: 2.1984 - dense_624_loss: 1.4361 - dense_625_loss: 2.1152 - dense_626_loss: 1.4951 - dense_627_loss: 1.8376 - dense_628_loss: 2.3072 - dense_629_loss: 0.7278 - dense_630_loss: 2.0153 - dense_631_loss: 0.5369 - dense_632_loss: 1.5691 - dense_633_loss: 1.1659 - dense_634_loss: 1.6091 - dense_635_loss: 1.9042 - dense_636_loss: 0.9606 - dense_637_loss: 1.3599 - dense_638_loss: 0.6289 - dense_639_loss: 0.6327 - dense_640_loss: 0.5753 - dense_641_loss: 1.6735 - dense_642_loss: 1.7608 - dense_643_loss: 1.7575 - dense_644_loss: 1.9584 - dense_645_loss: 1.7496 - dense_646_loss: 1.6741 - dense_647_loss: 1.4248 - dense_648_loss: 0.6523 - dense_649_loss: 0.5609 - dense_650_loss: 0.6327 - dense_651_loss: 0.6115 - dense_652_loss: 0.8138 - dense_653_loss: 0.6245 - dense_654_loss: 0.5554 - dense_655_loss: 0.6812 - dense_656_loss: 0.5986 - dense_657_loss: 0.6125 - dense_658_loss: 0.5668 - dense_659_loss: 0.6181 - dense_660_loss: 0.6570 - dense_661_loss: 0.6978 - dense_662_loss: 0.6071 - dense_663_loss: 0.5992 - dense_664_loss: 0.6054 - dense_665_loss: 0.6770 - dense_666_loss: 1.5272 - dense_667_loss: 0.6171 - dense_668_loss: 0.6317 - dense_669_loss: 0.0000e+00 - dense_670_loss: 3.5770 - dense_671_loss: 1.6772 - dense_672_loss: 2.5722 - dense_673_loss: 0.5977 - dense_674_loss: 0.7005 - dense_675_loss: 0.9145 - dense_676_loss: 1.6662 - dense_677_loss: 1.6116 - dense_678_loss: 1.7088 - dense_679_loss: 0.5528 - num_output_loss: 0.7151 - lr: 0.0010
# Epoch 4/1000
# 27/27 [==============================] - 3s 116ms/step - loss: 119.1039 - dense_589_loss: 2.4257 - dense_590_loss: 1.4766 - dense_591_loss: 1.6150 - dense_592_loss: 3.2372 - dense_593_loss: 4.4586 - dense_594_loss: 4.2748 - dense_595_loss: 0.4674 - dense_596_loss: 4.2172 - dense_597_loss: 0.4618 - dense_598_loss: 0.6306 - dense_599_loss: 0.5015 - dense_600_loss: 0.5867 - dense_601_loss: 0.7234 - dense_602_loss: 0.6443 - dense_603_loss: 0.4656 - dense_604_loss: 0.5484 - dense_605_loss: 1.0374 - dense_606_loss: 0.5478 - dense_607_loss: 0.5636 - dense_608_loss: 3.7414 - dense_609_loss: 1.7886 - dense_610_loss: 3.0460 - dense_611_loss: 0.9679 - dense_612_loss: 2.6210 - dense_613_loss: 2.0656 - dense_614_loss: 2.0341 - dense_615_loss: 0.7769 - dense_616_loss: 2.4325 - dense_617_loss: 1.6568 - dense_618_loss: 2.5952 - dense_619_loss: 1.3497 - dense_620_loss: 1.6499 - dense_621_loss: 1.7923 - dense_622_loss: 0.5662 - dense_623_loss: 2.1047 - dense_624_loss: 1.2763 - dense_625_loss: 1.9100 - dense_626_loss: 1.2890 - dense_627_loss: 1.6889 - dense_628_loss: 2.0500 - dense_629_loss: 0.6832 - dense_630_loss: 1.9135 - dense_631_loss: 0.5043 - dense_632_loss: 1.3179 - dense_633_loss: 1.0409 - dense_634_loss: 1.4332 - dense_635_loss: 1.7036 - dense_636_loss: 0.8596 - dense_637_loss: 1.1599 - dense_638_loss: 0.5675 - dense_639_loss: 0.5536 - dense_640_loss: 0.5339 - dense_641_loss: 1.4882 - dense_642_loss: 1.5963 - dense_643_loss: 1.6102 - dense_644_loss: 1.7483 - dense_645_loss: 1.5887 - dense_646_loss: 1.4926 - dense_647_loss: 1.2693 - dense_648_loss: 0.5800 - dense_649_loss: 0.5462 - dense_650_loss: 0.5644 - dense_651_loss: 0.5359 - dense_652_loss: 0.6634 - dense_653_loss: 0.5408 - dense_654_loss: 0.4399 - dense_655_loss: 0.6279 - dense_656_loss: 0.5123 - dense_657_loss: 0.5494 - dense_658_loss: 0.4938 - dense_659_loss: 0.5550 - dense_660_loss: 0.5717 - dense_661_loss: 0.5936 - dense_662_loss: 0.5344 - dense_663_loss: 0.5304 - dense_664_loss: 0.5237 - dense_665_loss: 0.6235 - dense_666_loss: 1.4025 - dense_667_loss: 0.5394 - dense_668_loss: 0.5686 - dense_669_loss: 0.0000e+00 - dense_670_loss: 3.4798 - dense_671_loss: 1.5756 - dense_672_loss: 2.3876 - dense_673_loss: 0.5796 - dense_674_loss: 0.6151 - dense_675_loss: 0.8162 - dense_676_loss: 1.5544 - dense_677_loss: 1.5006 - dense_678_loss: 1.5610 - dense_679_loss: 0.4954 - num_output_loss: 0.6905 - lr: 0.0010
# Epoch 5/1000
# 27/27 [==============================] - 3s 117ms/step - loss: 109.4456 - dense_589_loss: 2.3179 - dense_590_loss: 1.3882 - dense_591_loss: 1.4798 - dense_592_loss: 3.0593 - dense_593_loss: 4.3608 - dense_594_loss: 4.1600 - dense_595_loss: 0.3837 - dense_596_loss: 4.0975 - dense_597_loss: 0.4262 - dense_598_loss: 0.5814 - dense_599_loss: 0.4623 - dense_600_loss: 0.5211 - dense_601_loss: 0.6538 - dense_602_loss: 0.6118 - dense_603_loss: 0.4274 - dense_604_loss: 0.4768 - dense_605_loss: 0.9730 - dense_606_loss: 0.4859 - dense_607_loss: 0.4939 - dense_608_loss: 3.5909 - dense_609_loss: 1.7257 - dense_610_loss: 2.9059 - dense_611_loss: 0.8720 - dense_612_loss: 2.5093 - dense_613_loss: 1.8728 - dense_614_loss: 1.8892 - dense_615_loss: 0.7366 - dense_616_loss: 2.2939 - dense_617_loss: 1.4274 - dense_618_loss: 2.3586 - dense_619_loss: 1.2097 - dense_620_loss: 1.4790 - dense_621_loss: 1.6064 - dense_622_loss: 0.5061 - dense_623_loss: 1.9674 - dense_624_loss: 1.1307 - dense_625_loss: 1.7324 - dense_626_loss: 1.1186 - dense_627_loss: 1.5513 - dense_628_loss: 1.8377 - dense_629_loss: 0.6359 - dense_630_loss: 1.8042 - dense_631_loss: 0.4912 - dense_632_loss: 1.1400 - dense_633_loss: 0.9537 - dense_634_loss: 1.2950 - dense_635_loss: 1.5213 - dense_636_loss: 0.7621 - dense_637_loss: 1.0158 - dense_638_loss: 0.5102 - dense_639_loss: 0.4956 - dense_640_loss: 0.4943 - dense_641_loss: 1.2981 - dense_642_loss: 1.4028 - dense_643_loss: 1.4543 - dense_644_loss: 1.5132 - dense_645_loss: 1.4050 - dense_646_loss: 1.3046 - dense_647_loss: 1.0949 - dense_648_loss: 0.5147 - dense_649_loss: 0.5091 - dense_650_loss: 0.5073 - dense_651_loss: 0.4562 - dense_652_loss: 0.5557 - dense_653_loss: 0.4635 - dense_654_loss: 0.3487 - dense_655_loss: 0.5676 - dense_656_loss: 0.4296 - dense_657_loss: 0.4765 - dense_658_loss: 0.4170 - dense_659_loss: 0.4820 - dense_660_loss: 0.4896 - dense_661_loss: 0.5027 - dense_662_loss: 0.4517 - dense_663_loss: 0.4620 - dense_664_loss: 0.4394 - dense_665_loss: 0.5642 - dense_666_loss: 1.2780 - dense_667_loss: 0.4605 - dense_668_loss: 0.4960 - dense_669_loss: 0.0000e+00 - dense_670_loss: 3.3887 - dense_671_loss: 1.4436 - dense_672_loss: 2.2732 - dense_673_loss: 0.5505 - dense_674_loss: 0.5355 - dense_675_loss: 0.7039 - dense_676_loss: 1.4284 - dense_677_loss: 1.4148 - dense_678_loss: 1.4556 - dense_679_loss: 0.4361 - num_output_loss: 0.6687 - lr: 0.0010
# Epoch 6/1000
# 27/27 [==============================] - 3s 116ms/step - loss: 100.4373 - dense_589_loss: 2.2138 - dense_590_loss: 1.3362 - dense_591_loss: 1.4074 - dense_592_loss: 2.8806 - dense_593_loss: 4.2571 - dense_594_loss: 4.0732 - dense_595_loss: 0.3077 - dense_596_loss: 3.9875 - dense_597_loss: 0.4206 - dense_598_loss: 0.5190 - dense_599_loss: 0.4350 - dense_600_loss: 0.4446 - dense_601_loss: 0.5820 - dense_602_loss: 0.6011 - dense_603_loss: 0.3723 - dense_604_loss: 0.4084 - dense_605_loss: 0.9140 - dense_606_loss: 0.4445 - dense_607_loss: 0.4225 - dense_608_loss: 3.4001 - dense_609_loss: 1.6293 - dense_610_loss: 2.7809 - dense_611_loss: 0.7481 - dense_612_loss: 2.3939 - dense_613_loss: 1.6609 - dense_614_loss: 1.7371 - dense_615_loss: 0.7482 - dense_616_loss: 2.1861 - dense_617_loss: 1.2841 - dense_618_loss: 2.1489 - dense_619_loss: 1.1420 - dense_620_loss: 1.3752 - dense_621_loss: 1.4954 - dense_622_loss: 0.4334 - dense_623_loss: 1.8376 - dense_624_loss: 1.0197 - dense_625_loss: 1.5760 - dense_626_loss: 0.9962 - dense_627_loss: 1.4451 - dense_628_loss: 1.6229 - dense_629_loss: 0.5684 - dense_630_loss: 1.6678 - dense_631_loss: 0.4683 - dense_632_loss: 1.0364 - dense_633_loss: 0.8887 - dense_634_loss: 1.1807 - dense_635_loss: 1.3995 - dense_636_loss: 0.6695 - dense_637_loss: 0.9580 - dense_638_loss: 0.4832 - dense_639_loss: 0.4683 - dense_640_loss: 0.4598 - dense_641_loss: 1.0858 - dense_642_loss: 1.1701 - dense_643_loss: 1.2660 - dense_644_loss: 1.2528 - dense_645_loss: 1.1980 - dense_646_loss: 1.0844 - dense_647_loss: 0.9142 - dense_648_loss: 0.4583 - dense_649_loss: 0.4929 - dense_650_loss: 0.4323 - dense_651_loss: 0.3639 - dense_652_loss: 0.4681 - dense_653_loss: 0.3878 - dense_654_loss: 0.2748 - dense_655_loss: 0.4955 - dense_656_loss: 0.3410 - dense_657_loss: 0.4210 - dense_658_loss: 0.3484 - dense_659_loss: 0.3915 - dense_660_loss: 0.4009 - dense_661_loss: 0.4188 - dense_662_loss: 0.3695 - dense_663_loss: 0.3820 - dense_664_loss: 0.3543 - dense_665_loss: 0.4804 - dense_666_loss: 1.1315 - dense_667_loss: 0.3853 - dense_668_loss: 0.4119 - dense_669_loss: 0.0000e+00 - dense_670_loss: 3.3063 - dense_671_loss: 1.3284 - dense_672_loss: 2.1094 - dense_673_loss: 0.5349 - dense_674_loss: 0.4559 - dense_675_loss: 0.6008 - dense_676_loss: 1.3126 - dense_677_loss: 1.3044 - dense_678_loss: 1.3518 - dense_679_loss: 0.3630 - num_output_loss: 0.6513 - lr: 0.0010
# Epoch 7/1000
# 27/27 [==============================] - 3s 115ms/step - loss: 92.4646 - dense_589_loss: 2.1195 - dense_590_loss: 1.3429 - dense_591_loss: 1.3925 - dense_592_loss: 2.7232 - dense_593_loss: 4.1822 - dense_594_loss: 3.9903 - dense_595_loss: 0.2446 - dense_596_loss: 3.9101 - dense_597_loss: 0.3932 - dense_598_loss: 0.4422 - dense_599_loss: 0.3671 - dense_600_loss: 0.3660 - dense_601_loss: 0.5032 - dense_602_loss: 0.5756 - dense_603_loss: 0.3518 - dense_604_loss: 0.3542 - dense_605_loss: 0.8397 - dense_606_loss: 0.4223 - dense_607_loss: 0.3516 - dense_608_loss: 3.1595 - dense_609_loss: 1.6350 - dense_610_loss: 2.7106 - dense_611_loss: 0.6226 - dense_612_loss: 2.3324 - dense_613_loss: 1.4482 - dense_614_loss: 1.6832 - dense_615_loss: 0.7129 - dense_616_loss: 2.1008 - dense_617_loss: 1.1737 - dense_618_loss: 1.9854 - dense_619_loss: 1.0537 - dense_620_loss: 1.2881 - dense_621_loss: 1.3483 - dense_622_loss: 0.3609 - dense_623_loss: 1.6777 - dense_624_loss: 0.9843 - dense_625_loss: 1.5152 - dense_626_loss: 0.9437 - dense_627_loss: 1.4066 - dense_628_loss: 1.4549 - dense_629_loss: 0.4943 - dense_630_loss: 1.4893 - dense_631_loss: 0.4422 - dense_632_loss: 0.9651 - dense_633_loss: 0.8426 - dense_634_loss: 1.1104 - dense_635_loss: 1.3097 - dense_636_loss: 0.5830 - dense_637_loss: 0.8894 - dense_638_loss: 0.4114 - dense_639_loss: 0.4455 - dense_640_loss: 0.4186 - dense_641_loss: 0.8930 - dense_642_loss: 0.9442 - dense_643_loss: 1.0476 - dense_644_loss: 1.0022 - dense_645_loss: 0.9770 - dense_646_loss: 0.8734 - dense_647_loss: 0.7237 - dense_648_loss: 0.3966 - dense_649_loss: 0.4542 - dense_650_loss: 0.3655 - dense_651_loss: 0.2892 - dense_652_loss: 0.3858 - dense_653_loss: 0.3170 - dense_654_loss: 0.2195 - dense_655_loss: 0.4107 - dense_656_loss: 0.2666 - dense_657_loss: 0.3413 - dense_658_loss: 0.2786 - dense_659_loss: 0.3101 - dense_660_loss: 0.3178 - dense_661_loss: 0.3424 - dense_662_loss: 0.2910 - dense_663_loss: 0.3081 - dense_664_loss: 0.2796 - dense_665_loss: 0.3998 - dense_666_loss: 0.9659 - dense_667_loss: 0.3131 - dense_668_loss: 0.3274 - dense_669_loss: 0.0000e+00 - dense_670_loss: 3.1933 - dense_671_loss: 1.2081 - dense_672_loss: 2.0195 - dense_673_loss: 0.4971 - dense_674_loss: 0.3743 - dense_675_loss: 0.5032 - dense_676_loss: 1.1994 - dense_677_loss: 1.2648 - dense_678_loss: 1.3194 - dense_679_loss: 0.3350 - num_output_loss: 0.6379 - lr: 0.0010
# Epoch 8/1000
# 27/27 [==============================] - 3s 116ms/step - loss: 83.1885 - dense_589_loss: 2.0278 - dense_590_loss: 1.2726 - dense_591_loss: 1.2892 - dense_592_loss: 2.5293 - dense_593_loss: 4.0875 - dense_594_loss: 3.8926 - dense_595_loss: 0.1930 - dense_596_loss: 3.8065 - dense_597_loss: 0.3797 - dense_598_loss: 0.3655 - dense_599_loss: 0.3216 - dense_600_loss: 0.2893 - dense_601_loss: 0.4132 - dense_602_loss: 0.5427 - dense_603_loss: 0.3254 - dense_604_loss: 0.2887 - dense_605_loss: 0.7679 - dense_606_loss: 0.4154 - dense_607_loss: 0.2898 - dense_608_loss: 2.9049 - dense_609_loss: 1.5222 - dense_610_loss: 2.5512 - dense_611_loss: 0.4904 - dense_612_loss: 2.2204 - dense_613_loss: 1.2397 - dense_614_loss: 1.5555 - dense_615_loss: 0.6970 - dense_616_loss: 1.9518 - dense_617_loss: 1.0637 - dense_618_loss: 1.7924 - dense_619_loss: 0.9861 - dense_620_loss: 1.1420 - dense_621_loss: 1.2261 - dense_622_loss: 0.3016 - dense_623_loss: 1.5434 - dense_624_loss: 0.8386 - dense_625_loss: 1.3301 - dense_626_loss: 0.8110 - dense_627_loss: 1.2378 - dense_628_loss: 1.2666 - dense_629_loss: 0.4030 - dense_630_loss: 1.2832 - dense_631_loss: 0.4168 - dense_632_loss: 0.8611 - dense_633_loss: 0.7770 - dense_634_loss: 0.9827 - dense_635_loss: 1.1771 - dense_636_loss: 0.5007 - dense_637_loss: 0.8096 - dense_638_loss: 0.3704 - dense_639_loss: 0.4207 - dense_640_loss: 0.3784 - dense_641_loss: 0.6822 - dense_642_loss: 0.7251 - dense_643_loss: 0.8228 - dense_644_loss: 0.7584 - dense_645_loss: 0.7416 - dense_646_loss: 0.6657 - dense_647_loss: 0.5491 - dense_648_loss: 0.3402 - dense_649_loss: 0.4374 - dense_650_loss: 0.3023 - dense_651_loss: 0.2113 - dense_652_loss: 0.3015 - dense_653_loss: 0.2476 - dense_654_loss: 0.1671 - dense_655_loss: 0.3296 - dense_656_loss: 0.1979 - dense_657_loss: 0.2723 - dense_658_loss: 0.2261 - dense_659_loss: 0.2269 - dense_660_loss: 0.2397 - dense_661_loss: 0.2715 - dense_662_loss: 0.2210 - dense_663_loss: 0.2370 - dense_664_loss: 0.2121 - dense_665_loss: 0.3075 - dense_666_loss: 0.7913 - dense_667_loss: 0.2442 - dense_668_loss: 0.2486 - dense_669_loss: 0.0000e+00 - dense_670_loss: 3.1029 - dense_671_loss: 1.0909 - dense_672_loss: 1.9055 - dense_673_loss: 0.4665 - dense_674_loss: 0.2917 - dense_675_loss: 0.4194 - dense_676_loss: 1.0813 - dense_677_loss: 1.1743 - dense_678_loss: 1.2298 - dense_679_loss: 0.2783 - num_output_loss: 0.6192 - lr: 0.0010
# Epoch 9/1000
# 27/27 [==============================] - 3s 112ms/step - loss: 75.5609 - dense_589_loss: 1.9404 - dense_590_loss: 1.2304 - dense_591_loss: 1.2586 - dense_592_loss: 2.3831 - dense_593_loss: 3.9960 - dense_594_loss: 3.8160 - dense_595_loss: 0.1432 - dense_596_loss: 3.7169 - dense_597_loss: 0.3818 - dense_598_loss: 0.3042 - dense_599_loss: 0.2763 - dense_600_loss: 0.2320 - dense_601_loss: 0.3291 - dense_602_loss: 0.5127 - dense_603_loss: 0.3013 - dense_604_loss: 0.2472 - dense_605_loss: 0.7022 - dense_606_loss: 0.3679 - dense_607_loss: 0.2273 - dense_608_loss: 2.6100 - dense_609_loss: 1.4517 - dense_610_loss: 2.4418 - dense_611_loss: 0.3764 - dense_612_loss: 2.1609 - dense_613_loss: 1.0166 - dense_614_loss: 1.4563 - dense_615_loss: 0.6586 - dense_616_loss: 1.8545 - dense_617_loss: 0.9852 - dense_618_loss: 1.6741 - dense_619_loss: 0.9429 - dense_620_loss: 1.0537 - dense_621_loss: 1.1381 - dense_622_loss: 0.2513 - dense_623_loss: 1.3780 - dense_624_loss: 0.7212 - dense_625_loss: 1.1897 - dense_626_loss: 0.7280 - dense_627_loss: 1.1191 - dense_628_loss: 1.0882 - dense_629_loss: 0.3117 - dense_630_loss: 1.0670 - dense_631_loss: 0.3794 - dense_632_loss: 0.8144 - dense_633_loss: 0.7266 - dense_634_loss: 0.9068 - dense_635_loss: 1.1088 - dense_636_loss: 0.4335 - dense_637_loss: 0.7721 - dense_638_loss: 0.3340 - dense_639_loss: 0.4236 - dense_640_loss: 0.3493 - dense_641_loss: 0.5207 - dense_642_loss: 0.5433 - dense_643_loss: 0.6415 - dense_644_loss: 0.5759 - dense_645_loss: 0.5650 - dense_646_loss: 0.4909 - dense_647_loss: 0.4068 - dense_648_loss: 0.2740 - dense_649_loss: 0.4100 - dense_650_loss: 0.2576 - dense_651_loss: 0.1525 - dense_652_loss: 0.2517 - dense_653_loss: 0.1956 - dense_654_loss: 0.1325 - dense_655_loss: 0.2527 - dense_656_loss: 0.1445 - dense_657_loss: 0.2170 - dense_658_loss: 0.1884 - dense_659_loss: 0.1618 - dense_660_loss: 0.1817 - dense_661_loss: 0.2100 - dense_662_loss: 0.1695 - dense_663_loss: 0.1925 - dense_664_loss: 0.1595 - dense_665_loss: 0.2363 - dense_666_loss: 0.6376 - dense_667_loss: 0.1886 - dense_668_loss: 0.1809 - dense_669_loss: 0.0000e+00 - dense_670_loss: 3.0490 - dense_671_loss: 0.9878 - dense_672_loss: 1.7998 - dense_673_loss: 0.4417 - dense_674_loss: 0.2349 - dense_675_loss: 0.3511 - dense_676_loss: 0.9633 - dense_677_loss: 1.0101 - dense_678_loss: 1.0587 - dense_679_loss: 0.2342 - num_output_loss: 0.6010 - lr: 0.0010
# Epoch 10/1000
# 27/27 [==============================] - 3s 111ms/step - loss: 69.5098 - dense_589_loss: 1.8620 - dense_590_loss: 1.2419 - dense_591_loss: 1.1722 - dense_592_loss: 2.2503 - dense_593_loss: 3.9225 - dense_594_loss: 3.7517 - dense_595_loss: 0.1105 - dense_596_loss: 3.6514 - dense_597_loss: 0.3493 - dense_598_loss: 0.2424 - dense_599_loss: 0.2522 - dense_600_loss: 0.1754 - dense_601_loss: 0.2572 - dense_602_loss: 0.4801 - dense_603_loss: 0.2709 - dense_604_loss: 0.2104 - dense_605_loss: 0.6381 - dense_606_loss: 0.3637 - dense_607_loss: 0.1874 - dense_608_loss: 2.2868 - dense_609_loss: 1.3723 - dense_610_loss: 2.3471 - dense_611_loss: 0.2796 - dense_612_loss: 2.0619 - dense_613_loss: 0.8425 - dense_614_loss: 1.3674 - dense_615_loss: 0.5974 - dense_616_loss: 1.7661 - dense_617_loss: 0.9973 - dense_618_loss: 1.6108 - dense_619_loss: 0.8942 - dense_620_loss: 1.0360 - dense_621_loss: 1.0558 - dense_622_loss: 0.2038 - dense_623_loss: 1.2007 - dense_624_loss: 0.7095 - dense_625_loss: 1.1914 - dense_626_loss: 0.7154 - dense_627_loss: 1.0917 - dense_628_loss: 1.0264 - dense_629_loss: 0.2426 - dense_630_loss: 0.8560 - dense_631_loss: 0.3603 - dense_632_loss: 0.7609 - dense_633_loss: 0.6649 - dense_634_loss: 0.8304 - dense_635_loss: 1.0329 - dense_636_loss: 0.3756 - dense_637_loss: 0.7191 - dense_638_loss: 0.2981 - dense_639_loss: 0.3919 - dense_640_loss: 0.3234 - dense_641_loss: 0.3862 - dense_642_loss: 0.3989 - dense_643_loss: 0.4855 - dense_644_loss: 0.4121 - dense_645_loss: 0.4182 - dense_646_loss: 0.3596 - dense_647_loss: 0.3017 - dense_648_loss: 0.2348 - dense_649_loss: 0.3960 - dense_650_loss: 0.2131 - dense_651_loss: 0.1085 - dense_652_loss: 0.1928 - dense_653_loss: 0.1535 - dense_654_loss: 0.1000 - dense_655_loss: 0.1856 - dense_656_loss: 0.1065 - dense_657_loss: 0.1553 - dense_658_loss: 0.1512 - dense_659_loss: 0.1289 - dense_660_loss: 0.1380 - dense_661_loss: 0.1647 - dense_662_loss: 0.1277 - dense_663_loss: 0.1539 - dense_664_loss: 0.1214 - dense_665_loss: 0.1751 - dense_666_loss: 0.5117 - dense_667_loss: 0.1470 - dense_668_loss: 0.1372 - dense_669_loss: 0.0000e+00 - dense_670_loss: 2.9653 - dense_671_loss: 0.9189 - dense_672_loss: 1.6915 - dense_673_loss: 0.4264 - dense_674_loss: 0.1800 - dense_675_loss: 0.3066 - dense_676_loss: 0.8770 - dense_677_loss: 0.9051 - dense_678_loss: 0.9667 - dense_679_loss: 0.2200 - num_output_loss: 0.5873 - lr: 0.0010
# Epoch 11/1000
# 27/27 [==============================] - 3s 111ms/step - loss: 63.3038 - dense_589_loss: 1.8107 - dense_590_loss: 1.1473 - dense_591_loss: 1.1068 - dense_592_loss: 2.1051 - dense_593_loss: 3.8269 - dense_594_loss: 3.6546 - dense_595_loss: 0.0895 - dense_596_loss: 3.5414 - dense_597_loss: 0.3335 - dense_598_loss: 0.2011 - dense_599_loss: 0.2202 - dense_600_loss: 0.1535 - dense_601_loss: 0.2041 - dense_602_loss: 0.4317 - dense_603_loss: 0.2622 - dense_604_loss: 0.1790 - dense_605_loss: 0.5659 - dense_606_loss: 0.3035 - dense_607_loss: 0.1571 - dense_608_loss: 1.9795 - dense_609_loss: 1.2870 - dense_610_loss: 2.2133 - dense_611_loss: 0.2333 - dense_612_loss: 1.9664 - dense_613_loss: 0.7231 - dense_614_loss: 1.2567 - dense_615_loss: 0.5537 - dense_616_loss: 1.6582 - dense_617_loss: 0.8981 - dense_618_loss: 1.4845 - dense_619_loss: 0.8465 - dense_620_loss: 0.9381 - dense_621_loss: 0.9524 - dense_622_loss: 0.1810 - dense_623_loss: 1.0620 - dense_624_loss: 0.6252 - dense_625_loss: 1.0527 - dense_626_loss: 0.6518 - dense_627_loss: 0.9725 - dense_628_loss: 0.8978 - dense_629_loss: 0.1776 - dense_630_loss: 0.7104 - dense_631_loss: 0.3276 - dense_632_loss: 0.6585 - dense_633_loss: 0.6025 - dense_634_loss: 0.7375 - dense_635_loss: 0.8979 - dense_636_loss: 0.3657 - dense_637_loss: 0.6331 - dense_638_loss: 0.2767 - dense_639_loss: 0.3754 - dense_640_loss: 0.3064 - dense_641_loss: 0.2869 - dense_642_loss: 0.2950 - dense_643_loss: 0.3612 - dense_644_loss: 0.3083 - dense_645_loss: 0.3049 - dense_646_loss: 0.2735 - dense_647_loss: 0.2304 - dense_648_loss: 0.1870 - dense_649_loss: 0.3817 - dense_650_loss: 0.1988 - dense_651_loss: 0.0825 - dense_652_loss: 0.1485 - dense_653_loss: 0.1216 - dense_654_loss: 0.0924 - dense_655_loss: 0.1429 - dense_656_loss: 0.0886 - dense_657_loss: 0.1245 - dense_658_loss: 0.1350 - dense_659_loss: 0.0896 - dense_660_loss: 0.1135 - dense_661_loss: 0.1322 - dense_662_loss: 0.0958 - dense_663_loss: 0.1240 - dense_664_loss: 0.1076 - dense_665_loss: 0.1416 - dense_666_loss: 0.4306 - dense_667_loss: 0.1100 - dense_668_loss: 0.1007 - dense_669_loss: 0.0000e+00 - dense_670_loss: 2.8580 - dense_671_loss: 0.8212 - dense_672_loss: 1.6327 - dense_673_loss: 0.4024 - dense_674_loss: 0.1494 - dense_675_loss: 0.2505 - dense_676_loss: 0.7780 - dense_677_loss: 0.7889 - dense_678_loss: 0.8643 - dense_679_loss: 0.1780 - num_output_loss: 0.5746 - lr: 0.0010
# Epoch 12/1000
# 27/27 [==============================] - 3s 112ms/step - loss: 59.2983 - dense_589_loss: 1.6870 - dense_590_loss: 1.1023 - dense_591_loss: 1.0410 - dense_592_loss: 2.0013 - dense_593_loss: 3.7488 - dense_594_loss: 3.5875 - dense_595_loss: 0.0821 - dense_596_loss: 3.4431 - dense_597_loss: 0.3199 - dense_598_loss: 0.1729 - dense_599_loss: 0.1909 - dense_600_loss: 0.1288 - dense_601_loss: 0.1666 - dense_602_loss: 0.4133 - dense_603_loss: 0.2625 - dense_604_loss: 0.1751 - dense_605_loss: 0.5367 - dense_606_loss: 0.3289 - dense_607_loss: 0.1449 - dense_608_loss: 1.7130 - dense_609_loss: 1.2423 - dense_610_loss: 2.1139 - dense_611_loss: 0.1889 - dense_612_loss: 1.9003 - dense_613_loss: 0.5989 - dense_614_loss: 1.1770 - dense_615_loss: 0.5380 - dense_616_loss: 1.5617 - dense_617_loss: 0.8481 - dense_618_loss: 1.3944 - dense_619_loss: 0.7891 - dense_620_loss: 0.8792 - dense_621_loss: 0.9089 - dense_622_loss: 0.1582 - dense_623_loss: 0.9333 - dense_624_loss: 0.5960 - dense_625_loss: 1.0029 - dense_626_loss: 0.6204 - dense_627_loss: 0.9052 - dense_628_loss: 0.8462 - dense_629_loss: 0.1474 - dense_630_loss: 0.5893 - dense_631_loss: 0.3052 - dense_632_loss: 0.6527 - dense_633_loss: 0.5936 - dense_634_loss: 0.6868 - dense_635_loss: 0.8747 - dense_636_loss: 0.3231 - dense_637_loss: 0.6033 - dense_638_loss: 0.2426 - dense_639_loss: 0.3731 - dense_640_loss: 0.2904 - dense_641_loss: 0.2246 - dense_642_loss: 0.2348 - dense_643_loss: 0.2811 - dense_644_loss: 0.2370 - dense_645_loss: 0.2356 - dense_646_loss: 0.2122 - dense_647_loss: 0.1797 - dense_648_loss: 0.1799 - dense_649_loss: 0.3886 - dense_650_loss: 0.1757 - dense_651_loss: 0.0629 - dense_652_loss: 0.1276 - dense_653_loss: 0.0943 - dense_654_loss: 0.0833 - dense_655_loss: 0.1148 - dense_656_loss: 0.0656 - dense_657_loss: 0.1056 - dense_658_loss: 0.1133 - dense_659_loss: 0.0746 - dense_660_loss: 0.0825 - dense_661_loss: 0.1074 - dense_662_loss: 0.0757 - dense_663_loss: 0.1176 - dense_664_loss: 0.0816 - dense_665_loss: 0.1080 - dense_666_loss: 0.3641 - dense_667_loss: 0.0960 - dense_668_loss: 0.0826 - dense_669_loss: 0.0000e+00 - dense_670_loss: 2.7623 - dense_671_loss: 0.7793 - dense_672_loss: 1.5625 - dense_673_loss: 0.3866 - dense_674_loss: 0.1201 - dense_675_loss: 0.2307 - dense_676_loss: 0.7498 - dense_677_loss: 0.7374 - dense_678_loss: 0.7878 - dense_679_loss: 0.1760 - num_output_loss: 0.5677 - lr: 0.0010
# Epoch 13/1000
# 27/27 [==============================] - 3s 112ms/step - loss: 55.7964 - dense_589_loss: 1.6433 - dense_590_loss: 1.0698 - dense_591_loss: 0.9811 - dense_592_loss: 1.8635 - dense_593_loss: 3.6617 - dense_594_loss: 3.4927 - dense_595_loss: 0.0571 - dense_596_loss: 3.3535 - dense_597_loss: 0.3080 - dense_598_loss: 0.1483 - dense_599_loss: 0.1848 - dense_600_loss: 0.1051 - dense_601_loss: 0.1375 - dense_602_loss: 0.4120 - dense_603_loss: 0.2374 - dense_604_loss: 0.1590 - dense_605_loss: 0.5041 - dense_606_loss: 0.2909 - dense_607_loss: 0.1341 - dense_608_loss: 1.4742 - dense_609_loss: 1.1584 - dense_610_loss: 1.9992 - dense_611_loss: 0.1607 - dense_612_loss: 1.8354 - dense_613_loss: 0.5527 - dense_614_loss: 1.0728 - dense_615_loss: 0.4741 - dense_616_loss: 1.4773 - dense_617_loss: 0.8388 - dense_618_loss: 1.3392 - dense_619_loss: 0.7789 - dense_620_loss: 0.8427 - dense_621_loss: 0.8645 - dense_622_loss: 0.1516 - dense_623_loss: 0.8579 - dense_624_loss: 0.5172 - dense_625_loss: 0.9260 - dense_626_loss: 0.5622 - dense_627_loss: 0.8259 - dense_628_loss: 0.7627 - dense_629_loss: 0.1137 - dense_630_loss: 0.4645 - dense_631_loss: 0.3045 - dense_632_loss: 0.6084 - dense_633_loss: 0.5680 - dense_634_loss: 0.6586 - dense_635_loss: 0.8373 - dense_636_loss: 0.3073 - dense_637_loss: 0.5825 - dense_638_loss: 0.2403 - dense_639_loss: 0.3701 - dense_640_loss: 0.2776 - dense_641_loss: 0.2119 - dense_642_loss: 0.2113 - dense_643_loss: 0.2550 - dense_644_loss: 0.2271 - dense_645_loss: 0.2178 - dense_646_loss: 0.1911 - dense_647_loss: 0.1456 - dense_648_loss: 0.1572 - dense_649_loss: 0.3690 - dense_650_loss: 0.1802 - dense_651_loss: 0.0515 - dense_652_loss: 0.1082 - dense_653_loss: 0.0856 - dense_654_loss: 0.0683 - dense_655_loss: 0.0856 - dense_656_loss: 0.0584 - dense_657_loss: 0.0872 - dense_658_loss: 0.1104 - dense_659_loss: 0.0610 - dense_660_loss: 0.0741 - dense_661_loss: 0.0950 - dense_662_loss: 0.0601 - dense_663_loss: 0.1026 - dense_664_loss: 0.0663 - dense_665_loss: 0.0904 - dense_666_loss: 0.3269 - dense_667_loss: 0.0737 - dense_668_loss: 0.0685 - dense_669_loss: 0.0000e+00 - dense_670_loss: 2.6709 - dense_671_loss: 0.7370 - dense_672_loss: 1.4620 - dense_673_loss: 0.3827 - dense_674_loss: 0.1007 - dense_675_loss: 0.2217 - dense_676_loss: 0.7069 - dense_677_loss: 0.6636 - dense_678_loss: 0.7280 - dense_679_loss: 0.1704 - num_output_loss: 0.5640 - lr: 0.0010
# Epoch 14/1000
# 27/27 [==============================] - 3s 111ms/step - loss: 52.6289 - dense_589_loss: 1.5843 - dense_590_loss: 0.9971 - dense_591_loss: 0.9680 - dense_592_loss: 1.8163 - dense_593_loss: 3.5588 - dense_594_loss: 3.4077 - dense_595_loss: 0.0641 - dense_596_loss: 3.2600 - dense_597_loss: 0.2884 - dense_598_loss: 0.1412 - dense_599_loss: 0.1711 - dense_600_loss: 0.1045 - dense_601_loss: 0.1131 - dense_602_loss: 0.3921 - dense_603_loss: 0.2419 - dense_604_loss: 0.1504 - dense_605_loss: 0.4864 - dense_606_loss: 0.2625 - dense_607_loss: 0.1203 - dense_608_loss: 1.2969 - dense_609_loss: 1.0826 - dense_610_loss: 1.9059 - dense_611_loss: 0.1517 - dense_612_loss: 1.7722 - dense_613_loss: 0.4818 - dense_614_loss: 1.0242 - dense_615_loss: 0.4482 - dense_616_loss: 1.3818 - dense_617_loss: 0.7948 - dense_618_loss: 1.2572 - dense_619_loss: 0.7364 - dense_620_loss: 0.7824 - dense_621_loss: 0.8270 - dense_622_loss: 0.1410 - dense_623_loss: 0.7431 - dense_624_loss: 0.5067 - dense_625_loss: 0.8842 - dense_626_loss: 0.5566 - dense_627_loss: 0.7761 - dense_628_loss: 0.7294 - dense_629_loss: 0.1007 - dense_630_loss: 0.4384 - dense_631_loss: 0.2929 - dense_632_loss: 0.5521 - dense_633_loss: 0.5321 - dense_634_loss: 0.5663 - dense_635_loss: 0.7755 - dense_636_loss: 0.2816 - dense_637_loss: 0.5505 - dense_638_loss: 0.2156 - dense_639_loss: 0.3723 - dense_640_loss: 0.2621 - dense_641_loss: 0.1709 - dense_642_loss: 0.1746 - dense_643_loss: 0.1993 - dense_644_loss: 0.1845 - dense_645_loss: 0.1633 - dense_646_loss: 0.1566 - dense_647_loss: 0.1179 - dense_648_loss: 0.1454 - dense_649_loss: 0.3446 - dense_650_loss: 0.1538 - dense_651_loss: 0.0485 - dense_652_loss: 0.0915 - dense_653_loss: 0.0728 - dense_654_loss: 0.0761 - dense_655_loss: 0.0733 - dense_656_loss: 0.0485 - dense_657_loss: 0.0779 - dense_658_loss: 0.0914 - dense_659_loss: 0.0510 - dense_660_loss: 0.0609 - dense_661_loss: 0.0801 - dense_662_loss: 0.0504 - dense_663_loss: 0.0974 - dense_664_loss: 0.0682 - dense_665_loss: 0.0726 - dense_666_loss: 0.3047 - dense_667_loss: 0.0664 - dense_668_loss: 0.0583 - dense_669_loss: 0.0000e+00 - dense_670_loss: 2.5671 - dense_671_loss: 0.7015 - dense_672_loss: 1.4191 - dense_673_loss: 0.3832 - dense_674_loss: 0.0877 - dense_675_loss: 0.1933 - dense_676_loss: 0.6641 - dense_677_loss: 0.5971 - dense_678_loss: 0.6438 - dense_679_loss: 0.1622 - num_output_loss: 0.5603 - lr: 0.0010
# Epoch 15/1000
# 27/27 [==============================] - 3s 112ms/step - loss: 49.8242 - dense_589_loss: 1.5462 - dense_590_loss: 0.9881 - dense_591_loss: 0.9311 - dense_592_loss: 1.7218 - dense_593_loss: 3.4828 - dense_594_loss: 3.3402 - dense_595_loss: 0.0522 - dense_596_loss: 3.1814 - dense_597_loss: 0.2643 - dense_598_loss: 0.1236 - dense_599_loss: 0.1461 - dense_600_loss: 0.0871 - dense_601_loss: 0.1044 - dense_602_loss: 0.3702 - dense_603_loss: 0.2372 - dense_604_loss: 0.1486 - dense_605_loss: 0.4624 - dense_606_loss: 0.2570 - dense_607_loss: 0.1002 - dense_608_loss: 1.1435 - dense_609_loss: 1.0188 - dense_610_loss: 1.8104 - dense_611_loss: 0.1306 - dense_612_loss: 1.7206 - dense_613_loss: 0.4711 - dense_614_loss: 0.9256 - dense_615_loss: 0.4054 - dense_616_loss: 1.3258 - dense_617_loss: 0.7649 - dense_618_loss: 1.1692 - dense_619_loss: 0.6929 - dense_620_loss: 0.7348 - dense_621_loss: 0.7585 - dense_622_loss: 0.1312 - dense_623_loss: 0.6956 - dense_624_loss: 0.4541 - dense_625_loss: 0.8136 - dense_626_loss: 0.5179 - dense_627_loss: 0.7236 - dense_628_loss: 0.6615 - dense_629_loss: 0.0808 - dense_630_loss: 0.3823 - dense_631_loss: 0.2871 - dense_632_loss: 0.4914 - dense_633_loss: 0.4903 - dense_634_loss: 0.5389 - dense_635_loss: 0.7346 - dense_636_loss: 0.2784 - dense_637_loss: 0.5040 - dense_638_loss: 0.1936 - dense_639_loss: 0.3585 - dense_640_loss: 0.2548 - dense_641_loss: 0.1556 - dense_642_loss: 0.1586 - dense_643_loss: 0.1819 - dense_644_loss: 0.1710 - dense_645_loss: 0.1566 - dense_646_loss: 0.1400 - dense_647_loss: 0.1001 - dense_648_loss: 0.1437 - dense_649_loss: 0.3378 - dense_650_loss: 0.1574 - dense_651_loss: 0.0339 - dense_652_loss: 0.0778 - dense_653_loss: 0.0594 - dense_654_loss: 0.0551 - dense_655_loss: 0.0586 - dense_656_loss: 0.0421 - dense_657_loss: 0.0675 - dense_658_loss: 0.0935 - dense_659_loss: 0.0428 - dense_660_loss: 0.0497 - dense_661_loss: 0.0682 - dense_662_loss: 0.0472 - dense_663_loss: 0.0814 - dense_664_loss: 0.0572 - dense_665_loss: 0.0664 - dense_666_loss: 0.2644 - dense_667_loss: 0.0572 - dense_668_loss: 0.0491 - dense_669_loss: 0.0000e+00 - dense_670_loss: 2.4809 - dense_671_loss: 0.6843 - dense_672_loss: 1.3434 - dense_673_loss: 0.3727 - dense_674_loss: 0.0743 - dense_675_loss: 0.1786 - dense_676_loss: 0.6415 - dense_677_loss: 0.5516 - dense_678_loss: 0.6035 - dense_679_loss: 0.1531 - num_output_loss: 0.5571 - lr: 0.0010
# Epoch 16/1000
# 27/27 [==============================] - 3s 112ms/step - loss: 47.0043 - dense_589_loss: 1.4882 - dense_590_loss: 0.8729 - dense_591_loss: 0.8698 - dense_592_loss: 1.6397 - dense_593_loss: 3.3632 - dense_594_loss: 3.2176 - dense_595_loss: 0.0515 - dense_596_loss: 3.0700 - dense_597_loss: 0.2596 - dense_598_loss: 0.1175 - dense_599_loss: 0.1268 - dense_600_loss: 0.0873 - dense_601_loss: 0.0888 - dense_602_loss: 0.3712 - dense_603_loss: 0.2374 - dense_604_loss: 0.1341 - dense_605_loss: 0.4594 - dense_606_loss: 0.2365 - dense_607_loss: 0.0972 - dense_608_loss: 1.0288 - dense_609_loss: 0.9114 - dense_610_loss: 1.7030 - dense_611_loss: 0.1281 - dense_612_loss: 1.6437 - dense_613_loss: 0.4353 - dense_614_loss: 0.8788 - dense_615_loss: 0.3856 - dense_616_loss: 1.2283 - dense_617_loss: 0.7214 - dense_618_loss: 1.1247 - dense_619_loss: 0.6651 - dense_620_loss: 0.6964 - dense_621_loss: 0.7393 - dense_622_loss: 0.1279 - dense_623_loss: 0.6406 - dense_624_loss: 0.4389 - dense_625_loss: 0.7386 - dense_626_loss: 0.4751 - dense_627_loss: 0.6601 - dense_628_loss: 0.6264 - dense_629_loss: 0.0664 - dense_630_loss: 0.3349 - dense_631_loss: 0.2712 - dense_632_loss: 0.4616 - dense_633_loss: 0.4599 - dense_634_loss: 0.4959 - dense_635_loss: 0.6836 - dense_636_loss: 0.2793 - dense_637_loss: 0.4637 - dense_638_loss: 0.1693 - dense_639_loss: 0.3406 - dense_640_loss: 0.2537 - dense_641_loss: 0.1315 - dense_642_loss: 0.1330 - dense_643_loss: 0.1513 - dense_644_loss: 0.1439 - dense_645_loss: 0.1226 - dense_646_loss: 0.1153 - dense_647_loss: 0.0823 - dense_648_loss: 0.1384 - dense_649_loss: 0.3178 - dense_650_loss: 0.1610 - dense_651_loss: 0.0301 - dense_652_loss: 0.0646 - dense_653_loss: 0.0559 - dense_654_loss: 0.0616 - dense_655_loss: 0.0519 - dense_656_loss: 0.0359 - dense_657_loss: 0.0567 - dense_658_loss: 0.0962 - dense_659_loss: 0.0319 - dense_660_loss: 0.0492 - dense_661_loss: 0.0597 - dense_662_loss: 0.0410 - dense_663_loss: 0.0810 - dense_664_loss: 0.0561 - dense_665_loss: 0.0591 - dense_666_loss: 0.2513 - dense_667_loss: 0.0491 - dense_668_loss: 0.0425 - dense_669_loss: 0.0000e+00 - dense_670_loss: 2.4005 - dense_671_loss: 0.6263 - dense_672_loss: 1.2919 - dense_673_loss: 0.3576 - dense_674_loss: 0.0670 - dense_675_loss: 0.1533 - dense_676_loss: 0.5962 - dense_677_loss: 0.5165 - dense_678_loss: 0.5632 - dense_679_loss: 0.1391 - num_output_loss: 0.5555 - lr: 0.0010
# Epoch 17/1000
# 27/27 [==============================] - 3s 112ms/step - loss: 45.6210 - dense_589_loss: 1.4217 - dense_590_loss: 0.9218 - dense_591_loss: 0.8606 - dense_592_loss: 1.6188 - dense_593_loss: 3.3079 - dense_594_loss: 3.1692 - dense_595_loss: 0.0464 - dense_596_loss: 3.0083 - dense_597_loss: 0.2558 - dense_598_loss: 0.1110 - dense_599_loss: 0.1484 - dense_600_loss: 0.0785 - dense_601_loss: 0.0796 - dense_602_loss: 0.3596 - dense_603_loss: 0.2263 - dense_604_loss: 0.1308 - dense_605_loss: 0.4573 - dense_606_loss: 0.2770 - dense_607_loss: 0.1007 - dense_608_loss: 0.9669 - dense_609_loss: 0.9245 - dense_610_loss: 1.6610 - dense_611_loss: 0.1151 - dense_612_loss: 1.5946 - dense_613_loss: 0.4288 - dense_614_loss: 0.8668 - dense_615_loss: 0.4008 - dense_616_loss: 1.2056 - dense_617_loss: 0.6870 - dense_618_loss: 1.0805 - dense_619_loss: 0.6430 - dense_620_loss: 0.6965 - dense_621_loss: 0.7044 - dense_622_loss: 0.1209 - dense_623_loss: 0.6008 - dense_624_loss: 0.3847 - dense_625_loss: 0.6939 - dense_626_loss: 0.4320 - dense_627_loss: 0.6104 - dense_628_loss: 0.5672 - dense_629_loss: 0.0574 - dense_630_loss: 0.3048 - dense_631_loss: 0.2707 - dense_632_loss: 0.4680 - dense_633_loss: 0.4415 - dense_634_loss: 0.4449 - dense_635_loss: 0.6303 - dense_636_loss: 0.2716 - dense_637_loss: 0.4337 - dense_638_loss: 0.1839 - dense_639_loss: 0.3514 - dense_640_loss: 0.2574 - dense_641_loss: 0.1144 - dense_642_loss: 0.1184 - dense_643_loss: 0.1329 - dense_644_loss: 0.1286 - dense_645_loss: 0.1124 - dense_646_loss: 0.1065 - dense_647_loss: 0.0864 - dense_648_loss: 0.1334 - dense_649_loss: 0.3145 - dense_650_loss: 0.1539 - dense_651_loss: 0.0306 - dense_652_loss: 0.0593 - dense_653_loss: 0.0402 - dense_654_loss: 0.0505 - dense_655_loss: 0.0417 - dense_656_loss: 0.0359 - dense_657_loss: 0.0658 - dense_658_loss: 0.0847 - dense_659_loss: 0.0310 - dense_660_loss: 0.0420 - dense_661_loss: 0.0535 - dense_662_loss: 0.0382 - dense_663_loss: 0.0773 - dense_664_loss: 0.0486 - dense_665_loss: 0.0508 - dense_666_loss: 0.2475 - dense_667_loss: 0.0411 - dense_668_loss: 0.0361 - dense_669_loss: 0.0000e+00 - dense_670_loss: 2.3412 - dense_671_loss: 0.6384 - dense_672_loss: 1.2283 - dense_673_loss: 0.3690 - dense_674_loss: 0.0602 - dense_675_loss: 0.1561 - dense_676_loss: 0.5455 - dense_677_loss: 0.4956 - dense_678_loss: 0.5393 - dense_679_loss: 0.1339 - num_output_loss: 0.5569 - lr: 0.0010
# Epoch 18/1000
# 27/27 [==============================] - 3s 112ms/step - loss: 43.8142 - dense_589_loss: 1.3963 - dense_590_loss: 0.9078 - dense_591_loss: 0.8075 - dense_592_loss: 1.5304 - dense_593_loss: 3.1979 - dense_594_loss: 3.0743 - dense_595_loss: 0.0340 - dense_596_loss: 2.9216 - dense_597_loss: 0.2589 - dense_598_loss: 0.0976 - dense_599_loss: 0.1217 - dense_600_loss: 0.0753 - dense_601_loss: 0.0701 - dense_602_loss: 0.3376 - dense_603_loss: 0.2129 - dense_604_loss: 0.1160 - dense_605_loss: 0.4261 - dense_606_loss: 0.2413 - dense_607_loss: 0.0965 - dense_608_loss: 0.9096 - dense_609_loss: 0.8253 - dense_610_loss: 1.5638 - dense_611_loss: 0.1034 - dense_612_loss: 1.5540 - dense_613_loss: 0.3890 - dense_614_loss: 0.7976 - dense_615_loss: 0.3668 - dense_616_loss: 1.1044 - dense_617_loss: 0.7238 - dense_618_loss: 1.0690 - dense_619_loss: 0.6160 - dense_620_loss: 0.6570 - dense_621_loss: 0.6879 - dense_622_loss: 0.0987 - dense_623_loss: 0.5443 - dense_624_loss: 0.4012 - dense_625_loss: 0.6807 - dense_626_loss: 0.4360 - dense_627_loss: 0.6179 - dense_628_loss: 0.5706 - dense_629_loss: 0.0525 - dense_630_loss: 0.2964 - dense_631_loss: 0.2611 - dense_632_loss: 0.4499 - dense_633_loss: 0.4446 - dense_634_loss: 0.4417 - dense_635_loss: 0.6178 - dense_636_loss: 0.2481 - dense_637_loss: 0.4292 - dense_638_loss: 0.1656 - dense_639_loss: 0.3521 - dense_640_loss: 0.2489 - dense_641_loss: 0.1140 - dense_642_loss: 0.1221 - dense_643_loss: 0.1357 - dense_644_loss: 0.1304 - dense_645_loss: 0.1039 - dense_646_loss: 0.1101 - dense_647_loss: 0.0727 - dense_648_loss: 0.1264 - dense_649_loss: 0.3150 - dense_650_loss: 0.1489 - dense_651_loss: 0.0271 - dense_652_loss: 0.0504 - dense_653_loss: 0.0522 - dense_654_loss: 0.0549 - dense_655_loss: 0.0406 - dense_656_loss: 0.0315 - dense_657_loss: 0.0507 - dense_658_loss: 0.0854 - dense_659_loss: 0.0290 - dense_660_loss: 0.0410 - dense_661_loss: 0.0481 - dense_662_loss: 0.0300 - dense_663_loss: 0.0786 - dense_664_loss: 0.0523 - dense_665_loss: 0.0438 - dense_666_loss: 0.2252 - dense_667_loss: 0.0398 - dense_668_loss: 0.0376 - dense_669_loss: 0.0000e+00 - dense_670_loss: 2.2364 - dense_671_loss: 0.5994 - dense_672_loss: 1.2095 - dense_673_loss: 0.3402 - dense_674_loss: 0.0597 - dense_675_loss: 0.1570 - dense_676_loss: 0.5271 - dense_677_loss: 0.4370 - dense_678_loss: 0.5111 - dense_679_loss: 0.1357 - num_output_loss: 0.5547 - lr: 0.0010
# Epoch 19/1000
# 27/27 [==============================] - 3s 111ms/step - loss: 42.2364 - dense_589_loss: 1.3569 - dense_590_loss: 0.8578 - dense_591_loss: 0.8291 - dense_592_loss: 1.4790 - dense_593_loss: 3.1197 - dense_594_loss: 3.0130 - dense_595_loss: 0.0495 - dense_596_loss: 2.8497 - dense_597_loss: 0.2646 - dense_598_loss: 0.1184 - dense_599_loss: 0.1319 - dense_600_loss: 0.0742 - dense_601_loss: 0.0609 - dense_602_loss: 0.3165 - dense_603_loss: 0.2126 - dense_604_loss: 0.1247 - dense_605_loss: 0.4220 - dense_606_loss: 0.2307 - dense_607_loss: 0.0879 - dense_608_loss: 0.8686 - dense_609_loss: 0.8372 - dense_610_loss: 1.5562 - dense_611_loss: 0.1238 - dense_612_loss: 1.5312 - dense_613_loss: 0.3794 - dense_614_loss: 0.7884 - dense_615_loss: 0.3454 - dense_616_loss: 1.0867 - dense_617_loss: 0.6789 - dense_618_loss: 0.9827 - dense_619_loss: 0.5759 - dense_620_loss: 0.6362 - dense_621_loss: 0.6483 - dense_622_loss: 0.1116 - dense_623_loss: 0.5331 - dense_624_loss: 0.3847 - dense_625_loss: 0.6450 - dense_626_loss: 0.4313 - dense_627_loss: 0.5923 - dense_628_loss: 0.5425 - dense_629_loss: 0.0424 - dense_630_loss: 0.2803 - dense_631_loss: 0.2497 - dense_632_loss: 0.3589 - dense_633_loss: 0.3853 - dense_634_loss: 0.3777 - dense_635_loss: 0.5607 - dense_636_loss: 0.2386 - dense_637_loss: 0.3824 - dense_638_loss: 0.1628 - dense_639_loss: 0.3531 - dense_640_loss: 0.2055 - dense_641_loss: 0.1024 - dense_642_loss: 0.1070 - dense_643_loss: 0.1187 - dense_644_loss: 0.1182 - dense_645_loss: 0.0902 - dense_646_loss: 0.0921 - dense_647_loss: 0.0613 - dense_648_loss: 0.1369 - dense_649_loss: 0.2864 - dense_650_loss: 0.1320 - dense_651_loss: 0.0226 - dense_652_loss: 0.0467 - dense_653_loss: 0.0439 - dense_654_loss: 0.0523 - dense_655_loss: 0.0324 - dense_656_loss: 0.0309 - dense_657_loss: 0.0497 - dense_658_loss: 0.0744 - dense_659_loss: 0.0269 - dense_660_loss: 0.0318 - dense_661_loss: 0.0504 - dense_662_loss: 0.0294 - dense_663_loss: 0.0784 - dense_664_loss: 0.0469 - dense_665_loss: 0.0493 - dense_666_loss: 0.2170 - dense_667_loss: 0.0364 - dense_668_loss: 0.0372 - dense_669_loss: 0.0000e+00 - dense_670_loss: 2.1755 - dense_671_loss: 0.5732 - dense_672_loss: 1.1575 - dense_673_loss: 0.3197 - dense_674_loss: 0.0514 - dense_675_loss: 0.1385 - dense_676_loss: 0.5218 - dense_677_loss: 0.4335 - dense_678_loss: 0.4987 - dense_679_loss: 0.1355 - num_output_loss: 0.5536 - lr: 1.0000e-04
# Epoch 20/1000
# ...
# Epoch 24/1000
# 27/27 [==============================] - 3s 111ms/step - loss: 40.8755 - dense_589_loss: 1.3387 - dense_590_loss: 0.8329 - dense_591_loss: 0.7804 - dense_592_loss: 1.4650 - dense_593_loss: 3.0663 - dense_594_loss: 2.9607 - dense_595_loss: 0.0348 - dense_596_loss: 2.8031 - dense_597_loss: 0.2218 - dense_598_loss: 0.0964 - dense_599_loss: 0.1282 - dense_600_loss: 0.0742 - dense_601_loss: 0.0655 - dense_602_loss: 0.3305 - dense_603_loss: 0.2270 - dense_604_loss: 0.1085 - dense_605_loss: 0.4139 - dense_606_loss: 0.2152 - dense_607_loss: 0.0711 - dense_608_loss: 0.8101 - dense_609_loss: 0.7961 - dense_610_loss: 1.4805 - dense_611_loss: 0.1011 - dense_612_loss: 1.4728 - dense_613_loss: 0.3554 - dense_614_loss: 0.7067 - dense_615_loss: 0.3191 - dense_616_loss: 1.0183 - dense_617_loss: 0.6579 - dense_618_loss: 0.9798 - dense_619_loss: 0.5714 - dense_620_loss: 0.6167 - dense_621_loss: 0.6573 - dense_622_loss: 0.1020 - dense_623_loss: 0.5093 - dense_624_loss: 0.3558 - dense_625_loss: 0.6179 - dense_626_loss: 0.3985 - dense_627_loss: 0.5527 - dense_628_loss: 0.5182 - dense_629_loss: 0.0415 - dense_630_loss: 0.2653 - dense_631_loss: 0.2322 - dense_632_loss: 0.3808 - dense_633_loss: 0.3935 - dense_634_loss: 0.3872 - dense_635_loss: 0.5724 - dense_636_loss: 0.2277 - dense_637_loss: 0.3824 - dense_638_loss: 0.1626 - dense_639_loss: 0.3324 - dense_640_loss: 0.2148 - dense_641_loss: 0.0955 - dense_642_loss: 0.1071 - dense_643_loss: 0.1105 - dense_644_loss: 0.1155 - dense_645_loss: 0.0884 - dense_646_loss: 0.0925 - dense_647_loss: 0.0536 - dense_648_loss: 0.1088 - dense_649_loss: 0.2943 - dense_650_loss: 0.1335 - dense_651_loss: 0.0234 - dense_652_loss: 0.0398 - dense_653_loss: 0.0352 - dense_654_loss: 0.0436 - dense_655_loss: 0.0312 - dense_656_loss: 0.0256 - dense_657_loss: 0.0451 - dense_658_loss: 0.0670 - dense_659_loss: 0.0238 - dense_660_loss: 0.0349 - dense_661_loss: 0.0425 - dense_662_loss: 0.0236 - dense_663_loss: 0.0650 - dense_664_loss: 0.0436 - dense_665_loss: 0.0445 - dense_666_loss: 0.2155 - dense_667_loss: 0.0336 - dense_668_loss: 0.0327 - dense_669_loss: 0.0000e+00 - dense_670_loss: 2.1221 - dense_671_loss: 0.5758 - dense_672_loss: 1.1565 - dense_673_loss: 0.3268 - dense_674_loss: 0.0445 - dense_675_loss: 0.1260 - dense_676_loss: 0.4873 - dense_677_loss: 0.4003 - dense_678_loss: 0.4631 - dense_679_loss: 0.1271 - num_output_loss: 0.5509 - lr: 1.0000e-04
# Epoch 25/1000
# 27/27 [==============================] - 3s 111ms/step - loss: 41.1724 - dense_589_loss: 1.3429 - dense_590_loss: 0.8285 - dense_591_loss: 0.7935 - dense_592_loss: 1.4493 - dense_593_loss: 3.0664 - dense_594_loss: 2.9555 - dense_595_loss: 0.0357 - dense_596_loss: 2.8012 - dense_597_loss: 0.2394 - dense_598_loss: 0.0933 - dense_599_loss: 0.1149 - dense_600_loss: 0.0754 - dense_601_loss: 0.0671 - dense_602_loss: 0.3320 - dense_603_loss: 0.2376 - dense_604_loss: 0.1132 - dense_605_loss: 0.4102 - dense_606_loss: 0.2102 - dense_607_loss: 0.0774 - dense_608_loss: 0.8169 - dense_609_loss: 0.8080 - dense_610_loss: 1.4941 - dense_611_loss: 0.1060 - dense_612_loss: 1.4901 - dense_613_loss: 0.3628 - dense_614_loss: 0.7736 - dense_615_loss: 0.3315 - dense_616_loss: 1.0395 - dense_617_loss: 0.6662 - dense_618_loss: 1.0001 - dense_619_loss: 0.5700 - dense_620_loss: 0.6047 - dense_621_loss: 0.6806 - dense_622_loss: 0.1020 - dense_623_loss: 0.4951 - dense_624_loss: 0.3530 - dense_625_loss: 0.6152 - dense_626_loss: 0.4118 - dense_627_loss: 0.5464 - dense_628_loss: 0.5131 - dense_629_loss: 0.0395 - dense_630_loss: 0.2616 - dense_631_loss: 0.2323 - dense_632_loss: 0.4083 - dense_633_loss: 0.4106 - dense_634_loss: 0.4027 - dense_635_loss: 0.5992 - dense_636_loss: 0.2298 - dense_637_loss: 0.4169 - dense_638_loss: 0.1497 - dense_639_loss: 0.3232 - dense_640_loss: 0.2223 - dense_641_loss: 0.0950 - dense_642_loss: 0.0970 - dense_643_loss: 0.1076 - dense_644_loss: 0.1083 - dense_645_loss: 0.0814 - dense_646_loss: 0.0866 - dense_647_loss: 0.0624 - dense_648_loss: 0.1161 - dense_649_loss: 0.2797 - dense_650_loss: 0.1413 - dense_651_loss: 0.0222 - dense_652_loss: 0.0364 - dense_653_loss: 0.0408 - dense_654_loss: 0.0438 - dense_655_loss: 0.0298 - dense_656_loss: 0.0261 - dense_657_loss: 0.0450 - dense_658_loss: 0.0707 - dense_659_loss: 0.0234 - dense_660_loss: 0.0326 - dense_661_loss: 0.0419 - dense_662_loss: 0.0280 - dense_663_loss: 0.0656 - dense_664_loss: 0.0463 - dense_665_loss: 0.0430 - dense_666_loss: 0.2209 - dense_667_loss: 0.0315 - dense_668_loss: 0.0311 - dense_669_loss: 0.0000e+00 - dense_670_loss: 2.0973 - dense_671_loss: 0.5636 - dense_672_loss: 1.1435 - dense_673_loss: 0.3192 - dense_674_loss: 0.0502 - dense_675_loss: 0.1273 - dense_676_loss: 0.4835 - dense_677_loss: 0.4360 - dense_678_loss: 0.5071 - dense_679_loss: 0.1183 - num_output_loss: 0.5512 - lr: 1.0000e-05
# Epoch 26/1000
# 27/27 [==============================] - 3s 112ms/step - loss: 40.3415 - dense_589_loss: 1.3299 - dense_590_loss: 0.8193 - dense_591_loss: 0.7697 - dense_592_loss: 1.4417 - dense_593_loss: 3.0473 - dense_594_loss: 2.9194 - dense_595_loss: 0.0324 - dense_596_loss: 2.7842 - dense_597_loss: 0.1963 - dense_598_loss: 0.0962 - dense_599_loss: 0.1241 - dense_600_loss: 0.0696 - dense_601_loss: 0.0626 - dense_602_loss: 0.3129 - dense_603_loss: 0.2099 - dense_604_loss: 0.1138 - dense_605_loss: 0.4140 - dense_606_loss: 0.2079 - dense_607_loss: 0.0758 - dense_608_loss: 0.8114 - dense_609_loss: 0.7647 - dense_610_loss: 1.4490 - dense_611_loss: 0.0946 - dense_612_loss: 1.4555 - dense_613_loss: 0.3611 - dense_614_loss: 0.7277 - dense_615_loss: 0.3347 - dense_616_loss: 1.0000 - dense_617_loss: 0.6417 - dense_618_loss: 0.9784 - dense_619_loss: 0.5473 - dense_620_loss: 0.6139 - dense_621_loss: 0.6457 - dense_622_loss: 0.1053 - dense_623_loss: 0.5063 - dense_624_loss: 0.3420 - dense_625_loss: 0.6220 - dense_626_loss: 0.4081 - dense_627_loss: 0.5520 - dense_628_loss: 0.5142 - dense_629_loss: 0.0421 - dense_630_loss: 0.2580 - dense_631_loss: 0.2243 - dense_632_loss: 0.3565 - dense_633_loss: 0.3746 - dense_634_loss: 0.3537 - dense_635_loss: 0.5301 - dense_636_loss: 0.2308 - dense_637_loss: 0.3629 - dense_638_loss: 0.1543 - dense_639_loss: 0.3428 - dense_640_loss: 0.2100 - dense_641_loss: 0.0870 - dense_642_loss: 0.0966 - dense_643_loss: 0.1055 - dense_644_loss: 0.1096 - dense_645_loss: 0.0873 - dense_646_loss: 0.0895 - dense_647_loss: 0.0577 - dense_648_loss: 0.1072 - dense_649_loss: 0.2933 - dense_650_loss: 0.1285 - dense_651_loss: 0.0216 - dense_652_loss: 0.0370 - dense_653_loss: 0.0361 - dense_654_loss: 0.0440 - dense_655_loss: 0.0277 - dense_656_loss: 0.0258 - dense_657_loss: 0.0449 - dense_658_loss: 0.0696 - dense_659_loss: 0.0225 - dense_660_loss: 0.0317 - dense_661_loss: 0.0406 - dense_662_loss: 0.0270 - dense_663_loss: 0.0656 - dense_664_loss: 0.0511 - dense_665_loss: 0.0425 - dense_666_loss: 0.2232 - dense_667_loss: 0.0329 - dense_668_loss: 0.0311 - dense_669_loss: 0.0000e+00 - dense_670_loss: 2.1115 - dense_671_loss: 0.5467 - dense_672_loss: 1.1351 - dense_673_loss: 0.3370 - dense_674_loss: 0.0491 - dense_675_loss: 0.1367 - dense_676_loss: 0.5081 - dense_677_loss: 0.4065 - dense_678_loss: 0.4571 - dense_679_loss: 0.1242 - num_output_loss: 0.5498 - lr: 1.0000e-05
# Epoch 27/1000
# 27/27 [==============================] - 3s 112ms/step - loss: 40.5880 - dense_589_loss: 1.3114 - dense_590_loss: 0.8407 - dense_591_loss: 0.7821 - dense_592_loss: 1.4469 - dense_593_loss: 3.0579 - dense_594_loss: 2.9252 - dense_595_loss: 0.0385 - dense_596_loss: 2.7730 - dense_597_loss: 0.2198 - dense_598_loss: 0.1009 - dense_599_loss: 0.1206 - dense_600_loss: 0.0663 - dense_601_loss: 0.0653 - dense_602_loss: 0.3372 - dense_603_loss: 0.2240 - dense_604_loss: 0.1066 - dense_605_loss: 0.4264 - dense_606_loss: 0.2082 - dense_607_loss: 0.0841 - dense_608_loss: 0.8198 - dense_609_loss: 0.7673 - dense_610_loss: 1.4763 - dense_611_loss: 0.0982 - dense_612_loss: 1.4734 - dense_613_loss: 0.3611 - dense_614_loss: 0.7388 - dense_615_loss: 0.3298 - dense_616_loss: 1.0281 - dense_617_loss: 0.6341 - dense_618_loss: 0.9486 - dense_619_loss: 0.5282 - dense_620_loss: 0.5980 - dense_621_loss: 0.6344 - dense_622_loss: 0.1009 - dense_623_loss: 0.4920 - dense_624_loss: 0.3438 - dense_625_loss: 0.6031 - dense_626_loss: 0.4020 - dense_627_loss: 0.5258 - dense_628_loss: 0.5324 - dense_629_loss: 0.0422 - dense_630_loss: 0.2842 - dense_631_loss: 0.2256 - dense_632_loss: 0.3719 - dense_633_loss: 0.3884 - dense_634_loss: 0.3736 - dense_635_loss: 0.5476 - dense_636_loss: 0.2312 - dense_637_loss: 0.3667 - dense_638_loss: 0.1568 - dense_639_loss: 0.3235 - dense_640_loss: 0.2327 - dense_641_loss: 0.0916 - dense_642_loss: 0.0996 - dense_643_loss: 0.1056 - dense_644_loss: 0.1053 - dense_645_loss: 0.0838 - dense_646_loss: 0.0872 - dense_647_loss: 0.0578 - dense_648_loss: 0.1111 - dense_649_loss: 0.2966 - dense_650_loss: 0.1317 - dense_651_loss: 0.0220 - dense_652_loss: 0.0403 - dense_653_loss: 0.0380 - dense_654_loss: 0.0454 - dense_655_loss: 0.0283 - dense_656_loss: 0.0255 - dense_657_loss: 0.0441 - dense_658_loss: 0.0724 - dense_659_loss: 0.0224 - dense_660_loss: 0.0341 - dense_661_loss: 0.0391 - dense_662_loss: 0.0242 - dense_663_loss: 0.0672 - dense_664_loss: 0.0418 - dense_665_loss: 0.0449 - dense_666_loss: 0.2091 - dense_667_loss: 0.0330 - dense_668_loss: 0.0298 - dense_669_loss: 0.0000e+00 - dense_670_loss: 2.1246 - dense_671_loss: 0.5434 - dense_672_loss: 1.1672 - dense_673_loss: 0.3302 - dense_674_loss: 0.0495 - dense_675_loss: 0.1276 - dense_676_loss: 0.4871 - dense_677_loss: 0.4244 - dense_678_loss: 0.4935 - dense_679_loss: 0.1422 - num_output_loss: 0.5505 - lr: 1.0000e-05
# Epoch 28/1000
# 27/27 [==============================] - 3s 111ms/step - loss: 41.0387 - dense_589_loss: 1.3191 - dense_590_loss: 0.8389 - dense_591_loss: 0.7954 - dense_592_loss: 1.4624 - dense_593_loss: 3.0584 - dense_594_loss: 2.9633 - dense_595_loss: 0.0399 - dense_596_loss: 2.8093 - dense_597_loss: 0.2216 - dense_598_loss: 0.1004 - dense_599_loss: 0.1201 - dense_600_loss: 0.0750 - dense_601_loss: 0.0616 - dense_602_loss: 0.3262 - dense_603_loss: 0.2216 - dense_604_loss: 0.1207 - dense_605_loss: 0.4159 - dense_606_loss: 0.2180 - dense_607_loss: 0.0847 - dense_608_loss: 0.7942 - dense_609_loss: 0.8024 - dense_610_loss: 1.4733 - dense_611_loss: 0.1045 - dense_612_loss: 1.4784 - dense_613_loss: 0.3641 - dense_614_loss: 0.7222 - dense_615_loss: 0.3412 - dense_616_loss: 1.0365 - dense_617_loss: 0.6356 - dense_618_loss: 1.0047 - dense_619_loss: 0.5766 - dense_620_loss: 0.6293 - dense_621_loss: 0.6500 - dense_622_loss: 0.0947 - dense_623_loss: 0.4941 - dense_624_loss: 0.3749 - dense_625_loss: 0.6414 - dense_626_loss: 0.4193 - dense_627_loss: 0.5704 - dense_628_loss: 0.5409 - dense_629_loss: 0.0421 - dense_630_loss: 0.2665 - dense_631_loss: 0.2519 - dense_632_loss: 0.3860 - dense_633_loss: 0.3792 - dense_634_loss: 0.3792 - dense_635_loss: 0.5664 - dense_636_loss: 0.2314 - dense_637_loss: 0.3786 - dense_638_loss: 0.1593 - dense_639_loss: 0.3361 - dense_640_loss: 0.2214 - dense_641_loss: 0.0914 - dense_642_loss: 0.0962 - dense_643_loss: 0.1056 - dense_644_loss: 0.1108 - dense_645_loss: 0.0857 - dense_646_loss: 0.0877 - dense_647_loss: 0.0668 - dense_648_loss: 0.1076 - dense_649_loss: 0.2869 - dense_650_loss: 0.1275 - dense_651_loss: 0.0233 - dense_652_loss: 0.0357 - dense_653_loss: 0.0395 - dense_654_loss: 0.0514 - dense_655_loss: 0.0301 - dense_656_loss: 0.0286 - dense_657_loss: 0.0441 - dense_658_loss: 0.0723 - dense_659_loss: 0.0247 - dense_660_loss: 0.0338 - dense_661_loss: 0.0419 - dense_662_loss: 0.0269 - dense_663_loss: 0.0665 - dense_664_loss: 0.0431 - dense_665_loss: 0.0434 - dense_666_loss: 0.2097 - dense_667_loss: 0.0314 - dense_668_loss: 0.0307 - dense_669_loss: 0.0000e+00 - dense_670_loss: 2.1288 - dense_671_loss: 0.5799 - dense_672_loss: 1.1451 - dense_673_loss: 0.3184 - dense_674_loss: 0.0455 - dense_675_loss: 0.1318 - dense_676_loss: 0.4887 - dense_677_loss: 0.3973 - dense_678_loss: 0.4743 - dense_679_loss: 0.1343 - num_output_loss: 0.5521 - lr: 1.0000e-05
# Epoch 29/1000
# 27/27 [==============================] - 3s 111ms/step - loss: 40.6567 - dense_589_loss: 1.3252 - dense_590_loss: 0.8162 - dense_591_loss: 0.7856 - dense_592_loss: 1.4659 - dense_593_loss: 3.0614 - dense_594_loss: 2.9441 - dense_595_loss: 0.0358 - dense_596_loss: 2.7858 - dense_597_loss: 0.2258 - dense_598_loss: 0.1010 - dense_599_loss: 0.1199 - dense_600_loss: 0.0684 - dense_601_loss: 0.0615 - dense_602_loss: 0.3245 - dense_603_loss: 0.2058 - dense_604_loss: 0.1155 - dense_605_loss: 0.4067 - dense_606_loss: 0.2347 - dense_607_loss: 0.0784 - dense_608_loss: 0.8042 - dense_609_loss: 0.8117 - dense_610_loss: 1.4918 - dense_611_loss: 0.1024 - dense_612_loss: 1.4778 - dense_613_loss: 0.3630 - dense_614_loss: 0.7454 - dense_615_loss: 0.3433 - dense_616_loss: 1.0524 - dense_617_loss: 0.6089 - dense_618_loss: 0.9433 - dense_619_loss: 0.5396 - dense_620_loss: 0.5793 - dense_621_loss: 0.6130 - dense_622_loss: 0.1032 - dense_623_loss: 0.4974 - dense_624_loss: 0.3605 - dense_625_loss: 0.6103 - dense_626_loss: 0.3931 - dense_627_loss: 0.5511 - dense_628_loss: 0.5187 - dense_629_loss: 0.0394 - dense_630_loss: 0.2600 - dense_631_loss: 0.2378 - dense_632_loss: 0.3662 - dense_633_loss: 0.3873 - dense_634_loss: 0.3721 - dense_635_loss: 0.5611 - dense_636_loss: 0.2236 - dense_637_loss: 0.3730 - dense_638_loss: 0.1444 - dense_639_loss: 0.3469 - dense_640_loss: 0.2240 - dense_641_loss: 0.0881 - dense_642_loss: 0.0932 - dense_643_loss: 0.1034 - dense_644_loss: 0.1074 - dense_645_loss: 0.0836 - dense_646_loss: 0.0820 - dense_647_loss: 0.0606 - dense_648_loss: 0.1148 - dense_649_loss: 0.2700 - dense_650_loss: 0.1344 - dense_651_loss: 0.0236 - dense_652_loss: 0.0363 - dense_653_loss: 0.0387 - dense_654_loss: 0.0466 - dense_655_loss: 0.0281 - dense_656_loss: 0.0254 - dense_657_loss: 0.0448 - dense_658_loss: 0.0782 - dense_659_loss: 0.0213 - dense_660_loss: 0.0309 - dense_661_loss: 0.0415 - dense_662_loss: 0.0256 - dense_663_loss: 0.0677 - dense_664_loss: 0.0446 - dense_665_loss: 0.0404 - dense_666_loss: 0.2170 - dense_667_loss: 0.0364 - dense_668_loss: 0.0306 - dense_669_loss: 0.0000e+00 - dense_670_loss: 2.0915 - dense_671_loss: 0.5677 - dense_672_loss: 1.1647 - dense_673_loss: 0.3387 - dense_674_loss: 0.0452 - dense_675_loss: 0.1292 - dense_676_loss: 0.5036 - dense_677_loss: 0.4218 - dense_678_loss: 0.4897 - dense_679_loss: 0.1288 - num_output_loss: 0.5523 - lr: 1.0000e-05

# %%
import io

new_model = Model(inputs=total_input_li, outputs=encoder)
pred = new_model.predict(data_li)

out_v = io.open("vectors.tsv", "w", encoding="utf-8")
out_m = io.open("metadata.tsv", "w", encoding="utf-8")

phone_name = df_spec["phone"]
for n, (vec, phone) in enumerate(zip(pred, phone_name)):
    out_v.write("\t".join([str(x) for x in vec]) + "\n")
    out_m.write(phone + "\n")

out_v.close()
out_m.close()

# %%
from sklearn.metrics.pairwise import cosine_similarity

res = pd.DataFrame(pred, index=phone_name)
res = pd.DataFrame(cosine_similarity(res, res), index=phone_name, columns=phone_name)

col = [i for i in res.columns if "Samsung Galaxy S22 Ultra" in i]
print(col)

res[col].sort_values(col, ascending=False)
# Out:
# ['Samsung Galaxy S22 Ultra']
# phone                        Samsung Galaxy S22 Ultra
# phone
# Samsung Galaxy S22 Ultra                     0.999999
# Samsung Galaxy S21 Ultra                     0.860662
# Samsung Galaxy S22+                          0.837840
# Samsung Galaxy S22                           0.837545
# Samsung Galaxy Note20 Ultra                  0.830560
# ...                                               ...
# Xiaomi Redmi Note 10 Pro                     0.521004
# TCL 30                                       0.512490
# Doogee S59 Pro                               0.506948
# Doogee S59                                   0.505341
# Doogee X96 Pro                               0.475184
#
# [424 rows x 1 columns]

# %%
pred_li = model.predict(data_li)
pred_cols = cat_cols.copy()
pred_cols.append(num_cols)

res_li = []
for n, (col, data) in enumerate(zip(pred_cols, pred_li)):
    if n < len(pred_cols) - 1:
        data = [i.argmax() for i in data]
        res = pd.Series(data, name=col)
    else:
        res = pd.DataFrame(data, columns=col)
    res_li.append(res)

df_res = pd.concat(res_li, axis=1)[df_final.drop("phone", axis=1).columns]
df_res[num_cols] = scaler.inverse_transform(df_res[num_cols])

df_res.iloc[[65, 30, 34]]
# Out:
#              Size      Weight  Usable surface  Materials  Diagonal  Type  \
# 65  114454.992188  205.683304       87.383995          3  6.650398     4
# 30  110693.164062  210.692932       86.568939          0  6.150591     5
# 34  131040.742188  241.553055       89.338890          0  6.555308     5
#
#     Aspect Ratio     Density  Audio  Model  CPU  Nanometer  Frequency  \
# 65             3  407.142578     21    104   31   4.667629   2.635421
# 30             4  436.927307     34     92   31   7.839993   2.659733
# 34             3  449.682953     31     89   31   6.185626   2.721784
#
#     64 Bits  GPU        RAM    Capacity  SD Slot  Fingerprint  Proximity  \
# 65        1   23   5.508705  649.459717        1            1          0
# 30        1   23   9.271391  474.482452        0            1          0
# 34        1   23  10.256947  528.847778        0            1          0
#
#     Light sensor  Accelerometer  Compass  Gyroscope  RGB  Notifications LED  \
# 65             0              0        1          0    0                  0
# 30             0              0        0          0    1                  0
# 34             0              0        0          0    1                  0
#
#     Cooling system  Gaming buttons  Extra  Standard Resolution  \
# 65               0               0     50                    0
# 30               0               0     50                    1
# 34               1               0     50                    0
#
#     Standard Sensor  Standard Type  Standard Aperture  Standard ISO  \
# 65               38              2                  9             0
# 30               38              2                  9             0
# 34               38              2                  2             0
#
#     Standard Pixel size  Standard Pixel Binning  Standard Sensor size  \
# 65                    4                       1                     2
# 30                   12                       2                     2
# 34                    3                       2                     2
#
#     Wide Angle lens Resolution  Wide Angle lens Sensor  Wide Angle lens Type  \
# 65                           1                      22                     3
# 30                          10                      23                     0
# 34                           6                      22                     3
#
#     Wide Angle lens Aperture  Wide Angle lens Pixel size  \
# 65                         5                           4
# 30                         1                           8
# 34                         5                           4
#
#     Wide Angle lens Pixel Binning  Wide Angle lens Sensor size  \
# 65                              1                            1
# 30                              1                            1
# 34                              0                            1
#
#     Portrait mode (depth) Resolution  Portrait mode (depth) Sensor  \
# 65                                 7                            18
# 30                                 7                            18
# 34                                 7                            18
#
#     Portrait mode (depth) Type  Portrait mode (depth) Aperture  \
# 65                           5                               1
# 30                           5                               1
# 34                           5                               1
#
#     Portrait mode (depth) Pixel size  Portrait mode (depth) Pixel Binning  \
# 65                                10                                    1
# 30                                10                                    1
# 34                                10                                    1
#
#     Portrait mode (depth) Sensor size  Hall  Macro lens Aperture  \
# 65                                  6     0                    1
# 30                                  6     0                    1
# 34                                  6     0                    1
#
#     Macro lens Pixel size  Macro lens Resolution  Macro lens Sensor  \
# 65                      5                      5                 13
# 30                      5                      5                 13
# 34                      5                      5                 13
#
#     Macro lens Sensor size  Macro lens Type  Ultrasonic proximity virtual  \
# 65                       2                5                             1
# 30                       2                5                             1
# 34                       2                5                             1
#
#     Barometer  Geomagnetic  Telephoto + portrait Aperture  \
# 65          0            0                              0
# 30          0            0                              0
# 34          0            0                              3
#
#     Telephoto + portrait Pixel size  Telephoto + portrait Resolution  \
# 65                                6                                5
# 30                                6                                5
# 34                                6                                5
#
#     Telephoto + portrait Sensor  Telephoto + portrait Sensor size  \
# 65                            7                                 5
# 30                            7                                 5
# 34                            7                                 5
#
#     Telephoto + portrait Type  Cooling System  Heart Rate  Gravity  \
# 65                          5               3           0        1
# 30                          5               3           1        1
# 34                          5               3           1        1
#
#     Magnetometer  LiDAR Scanner  Red Core 1 Game chip  Display Pressure  \
# 65             1              1                     1                 1
# 30             1              1                     1                 1
# 34             1              1                     1                 1
#
#     Touch  BLE S Pen  Hardware  Utrasonic Fingerprint  Pedometer  \
# 65      1          1         1                      1          1
# 30      1          1         1                      1          1
# 34      1          1         1                      1          1
#
#     Telephoto + portrait Pixel Binning  Altimeter  Temperature  \
# 65                                   1          1            1
# 30                                   1          1            1
# 34                                   1          1            1
#
#     360° ambient light sensor  Iris scanner  Thermometer  Coulometer  \
# 65                          1             1            1           1
# 30                          1             1            1           1
# 34                          1             1            1           1
#
#      Secondary  UV light sensor  Humidity  Hall IC  Brand  Battery Capacity  \
# 65           4                1         1        0     35       2773.960205
# 30           4                1         1        0     35       4066.591309
# 34           4                1         1        0     35       3690.789062
#
#     Battery Type  Operating System  battery_Widevine L1  battery_Widevine L3  \
# 65             2                 2                    0                    1
# 30             0                 2                    0                    1
# 34             2                 2                    0                    1
#
#     Mil Spec  IP Grade  Resolution1  Resolution2  Fast charge  Charge Watt  \
# 65         2         4            7            7            1    65.224525
# 30         2         4            7            7            1    32.316998
# 34         2         4            7            7            1    38.450424
#
#     Month Diff
# 65   49.655731
# 30   43.217400
# 34   44.768291

# %%
df_final[df_final["phone"].isin(["Samsung Galaxy Note20 Ultra", "Samsung Galaxy S21 Ultra", "Samsung Galaxy S22 Ultra"])].sort_values("phone").drop_duplicates(subset=["phone"])
# Out:
#                           phone        Size  Weight  Usable surface  \
# 65  Samsung Galaxy Note20 Ultra  103052.736   209.0            92.0
# 30     Samsung Galaxy S21 Ultra  111085.884   227.0            89.0
# 34     Samsung Galaxy S22 Ultra  113217.523   227.0            89.0
#
#           Materials  Diagonal             Type Aspect Ratio  Density  \
# 65            Glass       6.9  UFS Storage 3.1       19.5:9    494.0
# 30            Glass       6.8  UFS Storage 3.1         20:9    516.0
# 34  Aluminium alloy       6.8  UFS Storage 3.1       19.5:9    501.0
#
#                                                 Audio                Model  \
# 65                      Dolby AtmosDolby Digital Plus   Samsung Exynos 990
# 30  Dolby AtmosHi-Res AudioNoise cancellation micr...  Samsung Exynos 2100
# 34  Dolby AtmosHi-Res AudioNoise cancellation micr...  Samsung Exynos 2200
#
#                                                   CPU  Nanometer  Frequency  \
# 65  2x Exynos M5 2.73 GHz + 2x Cortex•A76 2.5 GHz ...        7.0       2.73
# 30  1x Cortex•X1 2,91 GHz + 3x Cortex•A78 2,81 GHz...        5.0       2.91
# 34  1x2.8 GHz Cortex•X2 + 3x2.496 GHz Cortex•A710 ...        4.0       2.80
#
#    64 Bits                     GPU   RAM  Capacity SD Slot Fingerprint  \
# 65     Yes       ARM Mali-G77 MP11  12.0     512.0     Yes         Yes
# 30     Yes       ARM Mali-G78 MC14  16.0     512.0      No         Yes
# 34     Yes  AMD Xclipse 920 555MHz  12.0    1024.0      No         Yes
#
#    Proximity Light sensor Accelerometer Compass Gyroscope  RGB  \
# 65       Yes          Yes           Yes     NaN       Yes  Yes
# 30       Yes          Yes           Yes     Yes       Yes  NaN
# 34       Yes          Yes           Yes     Yes       Yes  NaN
#
#    Notifications LED Cooling system Gaming buttons Extra Standard Resolution  \
# 65                --             No             No   NaN             108 Mpx
# 30                --             No             No   NaN             108 Mpx
# 34                --            Yes             No   NaN             108 Mpx
#
#           Standard Sensor Standard Type Standard Aperture Standard ISO  \
# 65  Samsung Bright S5KHM1       ISOCELL            ƒ/ 1.8           --
# 30         Samsung S5KHM3       ISOCELL            ƒ/ 1.8           --
# 34         Samsung S5KHM3       ISOCELL            ƒ/ 1.8           --
#
#    Standard Pixel size Standard Pixel Binning Standard Sensor size  \
# 65             0.80 µm              1-9 (3x3)               1/1.33
# 30             0.80 µm              1-9 (3x3)               1/1.33
# 34             0.80 µm              1-9 (3x3)               1/1.33
#
#    Wide Angle lens Resolution Wide Angle lens Sensor Wide Angle lens Type  \
# 65                   12.2 Mpx         Samsung S5K2L3              ISOCELL
# 30                        NaN                    NaN                  NaN
# 34                   12.2 Mpx            Sony IMX563                 CMOS
#
#    Wide Angle lens Aperture Wide Angle lens Pixel size  \
# 65                   ƒ/ 2.2                    1.40 µm
# 30                      NaN                        NaN
# 34                   ƒ/ 2.2                    1.40 µm
#
#    Wide Angle lens Pixel Binning Wide Angle lens Sensor size  \
# 65                           NaN                       1/7.6
# 30                           NaN                         NaN
# 34                           NaN                      1/2.55
#
#    Portrait mode (depth) Resolution Portrait mode (depth) Sensor  \
# 65                              NaN                          NaN
# 30                              NaN                          NaN
# 34                              NaN                          NaN
#
#    Portrait mode (depth) Type Portrait mode (depth) Aperture  \
# 65                        NaN                            NaN
# 30                        NaN                            NaN
# 34                        NaN                            NaN
#
#    Portrait mode (depth) Pixel size Portrait mode (depth) Pixel Binning  \
# 65                              NaN                                 NaN
# 30                              NaN                                 NaN
# 34                              NaN                                 NaN
#
#    Portrait mode (depth) Sensor size Hall Macro lens Aperture  \
# 65                               NaN  Yes                 NaN
# 30                               NaN  Yes                 NaN
# 34                               NaN  Yes                 NaN
#
#    Macro lens Pixel size Macro lens Resolution Macro lens Sensor  \
# 65                   NaN                   NaN               NaN
# 30                   NaN                   NaN               NaN
# 34                   NaN                   NaN               NaN
#
#    Macro lens Sensor size Macro lens Type Ultrasonic proximity virtual  \
# 65                    NaN             NaN                          NaN
# 30                    NaN             NaN                          NaN
# 34                    NaN             NaN                          NaN
#
#    Barometer Geomagnetic Telephoto + portrait Aperture  \
# 65       Yes         Yes                           NaN
# 30       Yes         Yes                        ƒ/ 2.4
# 34       Yes         Yes                        ƒ/ 2.4
#
#    Telephoto + portrait Pixel size Telephoto + portrait Resolution  \
# 65                             NaN                             NaN
# 30                         1.22 µm                          10 Mpx
# 34                         1.12 µm                          12 Mpx
#
#    Telephoto + portrait Sensor Telephoto + portrait Sensor size  \
# 65                         NaN                              NaN
# 30              Samsung S5K3J1                           1/2.65
# 34                 Sony IMX754                           1/3.52
#
#    Telephoto + portrait Type Cooling System Heart Rate Gravity Magnetometer  \
# 65                       NaN            NaN        NaN     NaN          NaN
# 30                   ISOCELL            NaN        NaN     NaN          NaN
# 34                  CMOS BSI            NaN        NaN     NaN          NaN
#
#    LiDAR Scanner Red Core 1 Game chip Display Pressure Touch  \
# 65           NaN                  NaN              NaN   NaN
# 30           NaN                  NaN              NaN   NaN
# 34           NaN                  NaN              NaN   NaN
#
#                                             BLE S Pen Hardware  \
# 65  Bluetooth enabledLithium Titanate Battery: Up ...      NaN
# 30                                                NaN      NaN
# 34                                                NaN      NaN
#
#    Utrasonic Fingerprint Pedometer Telephoto + portrait Pixel Binning  \
# 65                   NaN       NaN                                NaN
# 30                   NaN       NaN                                NaN
# 34                   NaN       NaN                                NaN
#
#    Altimeter Temperature 360° ambient light sensor Iris scanner Thermometer  \
# 65       NaN         NaN                       NaN          NaN         NaN
# 30       NaN         NaN                       NaN          NaN         NaN
# 34       NaN         NaN                       NaN          NaN         NaN
#
#    Coulometer  Secondary UV light sensor Humidity Hall IC    Brand  \
# 65        NaN        NaN             NaN      NaN     NaN  Samsung
# 30        NaN        NaN             NaN      NaN     NaN  Samsung
# 34        NaN        NaN             NaN      NaN     NaN  Samsung
#
#     Battery Capacity Battery Type Operating System battery_Widevine L1  \
# 65            4500.0   Li-Polymer       Android 12                 Yes
# 30            5000.0   Li-Polymer       Android 12                 NaN
# 34            5000.0       Li-Ion       Android 12                 NaN
#
#    battery_Widevine L3 Mil Spec IP Grade Resolution1 Resolution2 Fast charge  \
# 65                 NaN      NaN     IP68       WQHD+       WQHD+         Yes
# 30                 NaN      NaN     IP68       WQHD+       WQHD+         Yes
# 34                 NaN      NaN     IP68       WQHD+       WQHD+         Yes
#
#     Charge Watt  Month Diff
# 65         45.0        24.0
# 30         25.0        19.0
# 34         45.0         6.0
